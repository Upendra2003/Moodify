# %%
import numpy as np
import pandas as pd
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense
from sklearn.model_selection import train_test_split
# Out:
# WARNING:tensorflow:From C:\Python310\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
# Load the dataset
df = pd.read_csv('improved_dataset.csv')

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\upend\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
import re
from nltk.stem.porter import PorterStemmer
from nltk.corpus import stopwords

# Initialize Porter Stemmer
stemmer = PorterStemmer()

# Load English stopwords
english_stopwords = set(stopwords.words("english"))

def preprocess_text(text):
    # Convert text to lowercase
    text = str(text).lower()
    
    # Remove URLs
    text = re.sub(r'https?://\S+|www\.\S+', '', text)
    
    # Remove HTML tags
    text = re.sub(r'<.*?>', '', text)
    
    # Remove digits and single characters
    text = re.sub(r'\b\w\b|\d+', '', text)
    
    # Remove punctuation
    text = re.sub(r'[^\w\s]', '', text)
    
    # Tokenize the text and remove stopwords
    words = [word for word in text.split() if word not in english_stopwords]
    
    # Stem the words
    stemmed_words = [stemmer.stem(word) for word in words]
    
    # Join the stemmed words back into a single string
    processed_text = ' '.join(stemmed_words)
    
    return processed_text

# Apply the preprocess_text function to the "text" column of your DataFrame
df["text"] = df["text"].apply(preprocess_text)

# %%
# Split the dataset into features and labels
X = data['text']
y = data['label']

# Tokenize the text
tokenizer = Tokenizer()
tokenizer.fit_on_texts(X)
X_seq = tokenizer.texts_to_sequences(X)

# Pad sequences to ensure uniform length
X_padded = pad_sequences(X_seq)

# Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_padded, y, test_size=0.2, random_state=42)

# %%
vocab_size = len(tokenizer.word_index) + 1
embedding_dim = 100
max_length = X_padded.shape[1]

model = Sequential()
model.add(Embedding(vocab_size, embedding_dim, input_length=max_length))
model.add(LSTM(128))
model.add(Dense(1, activation='sigmoid'))

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_1 (Embedding)     (None, 310, 100)          1214000
#
#  lstm_1 (LSTM)               (None, 128)               117248
#
#  dense_1 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 1331377 (5.08 MB)
# Trainable params: 1331377 (5.08 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
vocab_size
# Out:
# 12140

# %%
model.fit(X_train, y_train, epochs=10, batch_size=64, validation_data=(X_test, y_test))
# Out:
# Epoch 1/10
# 48/48 [==============================] - 33s 593ms/step - loss: 0.6506 - accuracy: 0.6144 - val_loss: 0.5201 - val_accuracy: 0.7762
# Epoch 2/10
# 48/48 [==============================] - 28s 581ms/step - loss: 0.3937 - accuracy: 0.8326 - val_loss: 0.4264 - val_accuracy: 0.7997
# Epoch 3/10
# 48/48 [==============================] - 28s 582ms/step - loss: 0.1897 - accuracy: 0.9302 - val_loss: 0.4645 - val_accuracy: 0.7840
# Epoch 4/10
# 48/48 [==============================] - 28s 574ms/step - loss: 0.0764 - accuracy: 0.9790 - val_loss: 0.6669 - val_accuracy: 0.7997
# Epoch 5/10
# 48/48 [==============================] - 28s 579ms/step - loss: 0.0443 - accuracy: 0.9882 - val_loss: 0.8034 - val_accuracy: 0.7932
# Epoch 6/10
# 48/48 [==============================] - 28s 578ms/step - loss: 0.0285 - accuracy: 0.9941 - val_loss: 0.7989 - val_accuracy: 0.7866
# Epoch 7/10
# 48/48 [==============================] - 28s 580ms/step - loss: 0.0221 - accuracy: 0.9944 - val_loss: 0.7410 - val_accuracy: 0.7723
# Epoch 8/10
# 48/48 [==============================] - 28s 581ms/step - loss: 0.0134 - accuracy: 0.9974 - val_loss: 0.8791 - val_accuracy: 0.7919
# Epoch 9/10
# 48/48 [==============================] - 27s 564ms/step - loss: 0.0050 - accuracy: 0.9990 - val_loss: 1.0382 - val_accuracy: 0.7893
# Epoch 10/10
# 48/48 [==============================] - 28s 583ms/step - loss: 0.0054 - accuracy: 0.9990 - val_loss: 0.9446 - val_accuracy: 0.7866

# %%
loss, accuracy = model.evaluate(X_test, y_test)
print('Test Accuracy:', accuracy)
# Out:
# 24/24 [==============================] - 3s 115ms/step - loss: 0.9446 - accuracy: 0.7866
# Test Accuracy: 0.786649227142334

# %%
# Preprocess the input text
def preprocess_input(text):
    # Tokenize the text
    text_seq = tokenizer.texts_to_sequences([text])
    # Pad sequences to ensure uniform length
    text_padded = pad_sequences(text_seq, maxlen=max_length)
    return text_padded

# Function to make predictions
def predict_sentiment(text):
    # Preprocess the input
    text_padded = preprocess_input(text)
    # Make predictions
    prediction = model.predict(text_padded)
    return prediction[0][0]

# Example usage
text = "my mom praised me and now i feel more enthusiastic, confident and joyful"
prediction = predict_sentiment(text)
def classify_stress(prediction, threshold=0.5):
    if prediction >= threshold:
        return str(f"Stressful+{prediction}")
    else:
        return str(f"Not Stressful+{prediction}")

# Example usage
stress_classification = classify_stress(prediction)
print("Classification:", stress_classification)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 19
#      17 # Example usage
#      18 text = "my mom praised me and now i feel more enthusiastic, confident and joyful"
# ---> 19 prediction = predict_sentiment(text)
#      20 def classify_stress(prediction, threshold=0.5):
#      21     if prediction >= threshold:
#
# Cell In[2], line 12, in predict_sentiment(text)
#      10 def predict_sentiment(text):
#      11     # Preprocess the input
# ---> 12     text_padded = preprocess_input(text)
#      13     # Make predictions
#      14     prediction = model.predict(text_padded)
#
# Cell In[2], line 4, in preprocess_input(text)
#       2 def preprocess_input(text):
#       3     # Tokenize the text
# ----> 4     text_seq = tokenizer.texts_to_sequences([text])
#       5     # Pad sequences to ensure uniform length
#       6     text_padded = pad_sequences(text_seq, maxlen=max_length)
#
# NameError: name 'tokenizer' is not defined

# %%
X_seq
# Out:
# [[19,
#   126,
#   19,
#   41,
#   26,
#   194,
#   10,
#   118,
#   132,
#   6517,
#   1,
#   70,
#   706,
#   3,
#   21,
#   876,
#   1089,
#   33,
#   6518,
#   5,
#   6519,
#   31,
#   8,
#   1,
#   1486,
#   2,
#   375,
#   38,
#   403,
#   7,
#   3299,
#   9,
#   1743,
#   7,
#   262,
#   156,
#   3885,
#   106,
#   68,
#   2890,
#   1307,
#   7,
#   6520,
#   6521,
#   5,
#   598,
#   50,
#   24,
#   3886,
#   1566,
#   29,
#   169,
#   495,
#   1254,
#   1308,
#   108,
#   1,
#   97,
#   63,
#   2139,
#   32,
#   152,
#   4,
#   903,
#   69,
#   1,
#   430,
#   38,
#   421,
#   10,
#   18,
#   677,
#   7,
#   3299,
#   53,
#   25,
#   6522,
#   7,
#   1744,
#   287,
#   4811,
#   61,
#   7,
#   112,
#   1,
#   51,
#   3300,
#   2,
#   21,
#   20,
#   659,
#   7,
#   6,
#   3299,
#   2,
#   6,
#   6523,
#   1,
#   51,
#   64,
#   6524,
#   466,
#   28,
#   6,
#   345,
#   1,
#   37,
#   446,
#   2,
#   16,
#   5,
#   474,
#   9,
#   6525,
#   293],
#  [756,
#   82,
#   586,
#   721,
#   26,
#   224,
#   33,
#   18,
#   13,
#   4,
#   157,
#   200,
#   2,
#   269,
#   18,
#   17,
#   124,
#   481,
#   27,
#   415,
#   5,
#   693,
#   6526,
#   32,
#   6527,
#   3887,
#   4812,
#   3,
#   267,
#   20,
#   5,
#   371,
#   2,
#   67,
#   1487,
#   104,
#   3888,
#   6528,
#   3301,
#   32,
#   4,
#   233,
#   2341,
#   34,
#   6529,
#   32,
#   154,
#   4,
#   678,
#   470,
#   255,
#   12,
#   587,
#   3889,
#   1860,
#   3302,
#   2342,
#   21,
#   33,
#   551,
#   5,
#   3302,
#   693,
#   29,
#   46,
#   3302,
#   2342,
#   1,
#   52,
#   877,
#   776,
#   33,
#   24,
#   53,
#   67,
#   128,
#   29,
#   1053,
#   531,
#   18,
#   388,
#   371,
#   36,
#   5,
#   274,
#   24,
#   230,
#   74,
#   611,
#   128,
#   4,
#   371,
#   66,
#   25,
#   2590,
#   9,
#   2,
#   5,
#   2891,
#   12,
#   679,
#   2,
#   1309,
#   61,
#   7,
#   444,
#   1018,
#   1198,
#   6530],
#  [6,
#   208,
#   99,
#   447,
#   8,
#   15,
#   4,
#   4813,
#   3,
#   11,
#   2140,
#   8,
#   10,
#   23,
#   52,
#   37,
#   18,
#   23,
#   482,
#   1,
#   56,
#   31,
#   519,
#   1381,
#   4814,
#   6531,
#   1381,
#   29,
#   925,
#   7,
#   81,
#   579,
#   20,
#   6,
#   162,
#   37,
#   1,
#   694,
#   35,
#   18,
#   3890,
#   393,
#   12,
#   11,
#   48,
#   4,
#   3891,
#   99,
#   847,
#   1,
#   376,
#   2,
#   128,
#   6,
#   177,
#   2,
#   70,
#   67,
#   228,
#   177,
#   288,
#   2,
#   5,
#   169,
#   200,
#   148,
#   34,
#   109,
#   832,
#   4,
#   177,
#   34,
#   50,
#   588,
#   6532,
#   8,
#   20,
#   6,
#   2591,
#   3,
#   1,
#   1310,
#   11,
#   722,
#   42,
#   18,
#   13,
#   4,
#   2892,
#   54,
#   1,
#   16,
#   114,
#   39,
#   26,
#   2,
#   37,
#   161,
#   92,
#   99,
#   6,
#   105,
#   177,
#   74,
#   13,
#   832,
#   777,
#   404,
#   106,
#   57,
#   6533,
#   15,
#   228,
#   236,
#   1,
#   93,
#   42,
#   19,
#   14,
#   386,
#   20,
#   3892,
#   3,
#   4,
#   177,
#   34,
#   50,
#   588,
#   9,
#   4,
#   6534,
#   13,
#   31,
#   24,
#   16,
#   2,
#   328,
#   1,
#   14,
#   30,
#   159,
#   2,
#   44,
#   88,
#   954,
#   24,
#   46,
#   4,
#   218,
#   280,
#   121,
#   3303,
#   37,
#   2,
#   44,
#   6535,
#   954,
#   85,
#   4814,
#   73,
#   18,
#   272,
#   13,
#   9,
#   62,
#   6536],
#  [178,
#   1,
#   325,
#   6,
#   169,
#   251,
#   19,
#   13,
#   514,
#   19,
#   13,
#   263,
#   19,
#   13,
#   1567,
#   19,
#   13,
#   5,
#   129,
#   693,
#   19,
#   1128,
#   4,
#   209,
#   92,
#   36,
#   8,
#   6,
#   119,
#   1128,
#   39,
#   3,
#   21,
#   20,
#   17,
#   1,
#   552,
#   49,
#   10,
#   571,
#   10,
#   2141,
#   1,
#   194,
#   15,
#   6,
#   357,
#   4,
#   1311,
#   13,
#   10,
#   43,
#   1,
#   153,
#   76,
#   35,
#   15,
#   6,
#   251,
#   1,
#   2893,
#   471,
#   6,
#   357,
#   5,
#   136,
#   188,
#   2,
#   120,
#   33,
#   1,
#   59,
#   1312,
#   49,
#   216,
#   12,
#   39,
#   17,
#   11,
#   14,
#   1019,
#   1,
#   1312,
#   63,
#   65,
#   39,
#   2,
#   878,
#   8,
#   1,
#   49,
#   160,
#   15,
#   101,
#   1,
#   1312,
#   65,
#   39,
#   17,
#   111,
#   1,
#   14,
#   82,
#   99,
#   1,
#   599,
#   848,
#   1,
#   194,
#   216,
#   150,
#   803,
#   12,
#   39,
#   3,
#   11,
#   14,
#   660,
#   19,
#   14,
#   634,
#   43,
#   19,
#   394,
#   1,
#   14,
#   448,
#   18,
#   1054,
#   3,
#   19,
#   63,
#   2142,
#   8,
#   2,
#   334,
#   17,
#   7,
#   483,
#   26,
#   17,
#   64,
#   4,
#   338,
#   13,
#   10,
#   43,
#   377,
#   15,
#   6,
#   251,
#   1,
#   552,
#   49,
#   31,
#   1,
#   150,
#   39,
#   31,
#   10,
#   218,
#   24,
#   599,
#   16,
#   2,
#   49,
#   15,
#   5,
#   169,
#   150,
#   1,
#   30,
#   49,
#   660,
#   15,
#   39,
#   3,
#   1,
#   1255,
#   101,
#   239,
#   28,
#   6,
#   357,
#   48,
#   54,
#   2,
#   54,
#   2343,
#   45,
#   4,
#   129,
#   92,
#   34,
#   41,
#   3,
#   11,
#   3893,
#   8,
#   405,
#   42,
#   1,
#   46,
#   10,
#   33,
#   1,
#   120,
#   39,
#   127,
#   1,
#   2143,
#   49,
#   10,
#   118,
#   10,
#   150,
#   10,
#   6,
#   314,
#   281,
#   8,
#   93,
#   6537,
#   82,
#   3,
#   286,
#   1,
#   275,
#   35,
#   10,
#   19,
#   55,
#   5,
#   353,
#   3,
#   19,
#   13,
#   260,
#   2894,
#   4,
#   361,
#   3,
#   1,
#   100,
#   21,
#   757,
#   3,
#   21,
#   634,
#   1,
#   46,
#   1,
#   552,
#   16,
#   81,
#   157,
#   2,
#   49,
#   10,
#   118,
#   1,
#   194,
#   3304,
#   3,
#   1,
#   111,
#   49,
#   10,
#   118,
#   1,
#   3305,
#   101,
#   35],
#  [1568,
#   13,
#   1090,
#   925,
#   1569,
#   237,
#   3,
#   1,
#   51,
#   5,
#   1090,
#   925,
#   1745,
#   74,
#   13,
#   111,
#   695,
#   63,
#   98,
#   90,
#   696,
#   91,
#   804,
#   1,
#   16,
#   47,
#   80,
#   79,
#   416,
#   416,
#   10,
#   6,
#   417,
#   357,
#   805,
#   69,
#   433,
#   2144,
#   12,
#   62,
#   1570,
#   18,
#   406,
#   545,
#   8,
#   9,
#   45,
#   6538,
#   553,
#   833,
#   955,
#   2592,
#   1091,
#   306,
#   1,
#   14,
#   4815,
#   5,
#   1746,
#   560,
#   589,
#   39,
#   3,
#   11,
#   14,
#   3894,
#   5,
#   121,
#   372,
#   17,
#   1,
#   14,
#   737,
#   2,
#   2895,
#   1747,
#   1313,
#   589,
#   39,
#   42,
#   1,
#   378,
#   16,
#   222,
#   1199,
#   2,
#   16,
#   5,
#   475],
#  [1,
#   93,
#   19,
#   203,
#   65,
#   2,
#   225,
#   9,
#   4,
#   1092,
#   12,
#   4,
#   141,
#   2,
#   83,
#   3,
#   470,
#   242,
#   21,
#   806,
#   10,
#   34,
#   16,
#   2,
#   83,
#   20,
#   104,
#   590,
#   203,
#   591,
#   15,
#   2344,
#   17,
#   19,
#   117,
#   25,
#   252,
#   8,
#   422,
#   40,
#   143,
#   1,
#   37,
#   27,
#   315,
#   18,
#   13,
#   778,
#   446,
#   90,
#   3,
#   90,
#   127,
#   42,
#   27,
#   149,
#   3306,
#   39,
#   32,
#   68,
#   195,
#   51,
#   1,
#   84,
#   4816,
#   531,
#   278,
#   247,
#   251,
#   1748,
#   1314,
#   437,
#   38,
#   15,
#   8,
#   1861,
#   1657,
#   98,
#   20,
#   115,
#   12,
#   326,
#   280,
#   91,
#   1,
#   168,
#   34,
#   30,
#   100,
#   11,
#   196,
#   3,
#   51,
#   2896,
#   56,
#   46,
#   40,
#   2,
#   37,
#   65,
#   2,
#   229,
#   984,
#   17,
#   143,
#   1],
#  [11,
#   14,
#   5,
#   449,
#   487,
#   21,
#   1571,
#   1,
#   137,
#   16,
#   2,
#   120,
#   39,
#   45,
#   4,
#   54,
#   17,
#   43,
#   1,
#   122,
#   19,
#   127,
#   2345,
#   36,
#   197,
#   1,
#   137,
#   1862,
#   1,
#   226,
#   2,
#   155,
#   2,
#   39,
#   3,
#   1256,
#   39,
#   20,
#   4,
#   1863,
#   3,
#   234,
#   39,
#   2,
#   25,
#   956,
#   12,
#   104,
#   3895,
#   1864,
#   3,
#   19,
#   476,
#   6539,
#   157,
#   138,
#   8,
#   252,
#   340,
#   5,
#   621,
#   198,
#   151,
#   98,
#   104,
#   738,
#   14,
#   1129,
#   1,
#   1382,
#   39,
#   3,
#   114,
#   39,
#   19,
#   14,
#   1257,
#   35,
#   20,
#   4,
#   184,
#   514,
#   162,
#   9,
#   18,
#   426,
#   3,
#   60,
#   11,
#   289,
#   1430,
#   2,
#   22,
#   2,
#   6,
#   1865,
#   19,
#   1315,
#   77,
#   3,
#   205,
#   2,
#   120,
#   22,
#   19,
#   2593,
#   126,
#   19,
#   41,
#   697,
#   3,
#   488,
#   5,
#   301,
#   7,
#   151,
#   34,
#   109,
#   1572],
#  [11,
#   2346,
#   38,
#   3,
#   1,
#   14,
#   515,
#   17,
#   20,
#   1431,
#   1,
#   14,
#   239,
#   28,
#   3307,
#   3,
#   60,
#   4,
#   358,
#   707,
#   3,
#   11,
#   4817,
#   8,
#   35,
#   1,
#   100,
#   466,
#   10,
#   42,
#   1,
#   14,
#   239,
#   28,
#   60,
#   4,
#   358,
#   707,
#   10,
#   1,
#   52,
#   450,
#   246,
#   3,
#   1,
#   122,
#   10,
#   174,
#   14,
#   160,
#   30,
#   31,
#   147,
#   54,
#   102,
#   847,
#   6,
#   246,
#   14,
#   160,
#   1,
#   985,
#   38,
#   31,
#   158,
#   561,
#   7,
#   4,
#   174,
#   30,
#   31,
#   147,
#   54,
#   1,
#   100,
#   263,
#   7,
#   298,
#   31,
#   1,
#   122,
#   147,
#   54,
#   17,
#   18,
#   54,
#   1,
#   93,
#   10,
#   18,
#   13,
#   1258,
#   89,
#   112,
#   13,
#   4818,
#   17,
#   1,
#   30,
#   93,
#   28,
#   11,
#   99,
#   44,
#   59,
#   298,
#   99,
#   1,
#   93,
#   2594,
#   99,
#   904,
#   152],
#  [1,
#   260,
#   248,
#   57,
#   6540,
#   484,
#   6,
#   1316,
#   2595,
#   2,
#   181,
#   67,
#   8,
#   294,
#   1,
#   49,
#   2897,
#   832,
#   2,
#   206,
#   1164,
#   9,
#   4,
#   849,
#   7,
#   4,
#   174,
#   85,
#   101,
#   1,
#   1749,
#   612,
#   6,
#   362,
#   531,
#   36,
#   5,
#   6541,
#   6542,
#   29,
#   43,
#   1,
#   49,
#   2897,
#   112,
#   13,
#   807,
#   2898,
#   2,
#   39,
#   1573,
#   362,
#   6,
#   362,
#   13,
#   1574,
#   242,
#   15,
#   62,
#   1432,
#   986,
#   4819,
#   3,
#   15,
#   104,
#   2596,
#   35,
#   124,
#   9,
#   4,
#   678,
#   34,
#   49,
#   31,
#   34,
#   16,
#   69,
#   350,
#   89,
#   35,
#   124],
#  [1,
#   30,
#   49,
#   31,
#   4,
#   1055,
#   89,
#   55,
#   1866,
#   6,
#   290,
#   38,
#   434,
#   21,
#   94,
#   1,
#   56,
#   63,
#   46,
#   60,
#   2,
#   155,
#   28,
#   282,
#   1,
#   30,
#   680,
#   10,
#   407,
#   110,
#   162,
#   1,
#   53,
#   59,
#   1993,
#   15,
#   13,
#   5,
#   6543,
#   1,
#   46,
#   32,
#   4,
#   1317,
#   19,
#   55,
#   191,
#   3,
#   407,
#   48,
#   4,
#   1750,
#   160,
#   199,
#   38,
#   1575,
#   4820,
#   98,
#   1200,
#   78,
#   34,
#   155,
#   238,
#   158,
#   136,
#   303,
#   3,
#   34,
#   50,
#   418,
#   3,
#   75,
#   1201,
#   17,
#   381,
#   78],
#  [219,
#   183,
#   905,
#   25,
#   2597,
#   12,
#   104,
#   119,
#   1658,
#   4,
#   4821,
#   1165,
#   25,
#   79,
#   163,
#   30,
#   4822,
#   2,
#   2899,
#   99,
#   4823,
#   2,
#   4822,
#   20,
#   4,
#   118,
#   139,
#   17,
#   2597,
#   59,
#   1166,
#   6,
#   86,
#   681,
#   1,
#   30,
#   31,
#   145,
#   458,
#   90,
#   101,
#   3,
#   6,
#   3308,
#   21,
#   4,
#   299,
#   7,
#   84,
#   9,
#   5,
#   3896,
#   4824,
#   592,
#   1867,
#   1318,
#   9,
#   4,
#   1751,
#   13,
#   26,
#   2900,
#   12,
#   8,
#   1,
#   102,
#   16,
#   5,
#   133,
#   7,
#   1433,
#   28,
#   6544,
#   467,
#   4825,
#   6545,
#   1752,
#   6546,
#   3,
#   105,
#   4826,
#   906,
#   957,
#   50,
#   102,
#   5,
#   338,
#   12,
#   8,
#   1,
#   14,
#   682,
#   33,
#   125,
#   55,
#   81,
#   1167,
#   12,
#   2597,
#   86,
#   363],
#  [171,
#   6547,
#   8,
#   115,
#   3,
#   27,
#   257,
#   145,
#   5,
#   322,
#   438,
#   27,
#   76,
#   2,
#   6,
#   2347,
#   489,
#   3,
#   10,
#   102,
#   281,
#   8,
#   341,
#   42,
#   27,
#   315,
#   10,
#   27,
#   26,
#   9,
#   4,
#   296,
#   622,
#   2,
#   70,
#   82,
#   3,
#   1,
#   65,
#   2,
#   334,
#   32,
#   6,
#   2145,
#   17,
#   19,
#   59,
#   397,
#   240,
#   43,
#   1,
#   37,
#   10,
#   459,
#   43,
#   23,
#   4827,
#   29,
#   13,
#   80,
#   160,
#   1,
#   1576,
#   22,
#   3,
#   71,
#   87,
#   1659,
#   6,
#   926,
#   32,
#   22,
#   63,
#   43,
#   808,
#   43,
#   23,
#   758,
#   1,
#   2901,
#   15,
#   22,
#   23,
#   2902,
#   22,
#   926,
#   1,
#   16,
#   2,
#   155,
#   28,
#   40,
#   23,
#   395,
#   2,
#   9,
#   879,
#   157,
#   64,
#   42,
#   23,
#   404,
#   3897,
#   1319,
#   1,
#   49,
#   31,
#   4828,
#   42,
#   23,
#   102,
#   55,
#   21,
#   233,
#   6548,
#   2903,
#   17,
#   1,
#   56,
#   65,
#   2,
#   450,
#   22,
#   36,
#   5,
#   177],
#  [212,
#   47,
#   335,
#   850,
#   280,
#   6549,
#   1660,
#   12,
#   28,
#   389,
#   151,
#   1434,
#   623,
#   408,
#   1994,
#   17,
#   11,
#   14,
#   335,
#   4,
#   1435,
#   115,
#   1,
#   93,
#   1,
#   376,
#   2,
#   245,
#   335,
#   11,
#   12,
#   5,
#   136,
#   201,
#   2,
#   120,
#   33,
#   11,
#   14,
#   59,
#   600,
#   64,
#   28,
#   1093,
#   293,
#   123,
#   6,
#   147,
#   1994,
#   95,
#   1056,
#   263,
#   7,
#   2348,
#   3,
#   102,
#   3898,
#   6,
#   6550,
#   50,
#   2349,
#   12,
#   69,
#   346,
#   3,
#   283,
#   423,
#   1094,
#   50,
#   28,
#   2,
#   1577,
#   8,
#   35,
#   37,
#   24,
#   93,
#   11,
#   13,
#   48,
#   6,
#   1488,
#   1994,
#   13,
#   11,
#   532,
#   2,
#   16,
#   424,
#   5,
#   739,
#   1753],
#  [69,
#   200,
#   9,
#   6,
#   537,
#   55,
#   759,
#   851,
#   12,
#   167,
#   3,
#   1,
#   435,
#   225,
#   6,
#   779,
#   20,
#   4,
#   6551,
#   1055,
#   71,
#   47,
#   82,
#   132,
#   460,
#   12,
#   169,
#   17,
#   1,
#   56,
#   65,
#   2,
#   16,
#   2,
#   70,
#   138,
#   10,
#   15,
#   5,
#   779,
#   40,
#   2146,
#   16,
#   129,
#   759,
#   2598,
#   12,
#   320,
#   2904,
#   3,
#   698,
#   331,
#   150,
#   2,
#   25,
#   185,
#   2,
#   107,
#   68,
#   1164,
#   3,
#   44,
#   20,
#   5,
#   4829,
#   400,
#   4,
#   2350,
#   3,
#   6552,
#   43,
#   276,
#   927,
#   25,
#   185,
#   2,
#   44,
#   4,
#   175,
#   2,
#   70],
#  [161,
#   213,
#   301,
#   7,
#   151,
#   16,
#   47,
#   4,
#   425,
#   6,
#   86,
#   55,
#   593,
#   21,
#   160,
#   207,
#   4830,
#   6,
#   246,
#   3,
#   141,
#   212,
#   439,
#   21,
#   1578,
#   28,
#   6,
#   287,
#   36,
#   146,
#   1,
#   187,
#   49,
#   31,
#   8,
#   282,
#   3,
#   1,
#   30,
#   49,
#   298,
#   45,
#   4,
#   54,
#   64,
#   90,
#   158,
#   172,
#   218,
#   1,
#   187,
#   16,
#   175,
#   2,
#   120,
#   5,
#   339,
#   422],
#  [1,
#   223,
#   39,
#   444,
#   54,
#   40,
#   190,
#   3,
#   98,
#   4,
#   1868,
#   54,
#   1,
#   1057,
#   3,
#   164,
#   139,
#   237,
#   372,
#   19,
#   111,
#   56,
#   155,
#   2,
#   8,
#   3,
#   19,
#   3,
#   6,
#   261,
#   153,
#   984,
#   12,
#   4,
#   130,
#   54,
#   9,
#   4,
#   141,
#   8,
#   3,
#   6,
#   261,
#   538,
#   56,
#   46,
#   40,
#   2,
#   37,
#   19,
#   30,
#   3309,
#   8,
#   1,
#   63,
#   114,
#   39,
#   10,
#   1,
#   56,
#   533,
#   10,
#   272,
#   63,
#   197,
#   1,
#   533,
#   39,
#   3,
#   19,
#   137,
#   63,
#   2147,
#   2,
#   11],
#  [4,
#   1869,
#   1995,
#   293,
#   11,
#   520,
#   31,
#   5,
#   6553,
#   338,
#   3,
#   1,
#   3310,
#   3,
#   7,
#   483,
#   430,
#   38,
#   9,
#   4,
#   1870,
#   127,
#   18,
#   54,
#   5,
#   539,
#   270,
#   2,
#   120,
#   8,
#   722,
#   19,
#   205,
#   2,
#   155,
#   28,
#   6,
#   86,
#   19,
#   126,
#   19,
#   97,
#   661,
#   68,
#   72,
#   1754,
#   17,
#   19,
#   137,
#   93,
#   11,
#   52,
#   67],
#  [11,
#   122,
#   634,
#   17,
#   378,
#   243,
#   81,
#   3311,
#   43,
#   1,
#   1579,
#   152,
#   1,
#   521,
#   3899,
#   3,
#   235,
#   11,
#   307,
#   599,
#   6554,
#   31,
#   1168,
#   5,
#   2599,
#   9,
#   6,
#   1755,
#   212,
#   3312,
#   3,
#   1996,
#   60,
#   834,
#   11,
#   53,
#   25,
#   3,
#   64,
#   95,
#   835,
#   17,
#   298,
#   2,
#   70,
#   539,
#   40,
#   37,
#   1,
#   37,
#   95,
#   26,
#   987,
#   461,
#   3,
#   1,
#   51,
#   26,
#   76,
#   2,
#   81,
#   496,
#   1,
#   66,
#   70,
#   2,
#   539,
#   33,
#   58,
#   50,
#   2148,
#   28,
#   11],
#  [18,
#   13,
#   600,
#   2,
#   44,
#   451,
#   9,
#   4,
#   635,
#   6555,
#   1756,
#   2,
#   2149,
#   3,
#   5,
#   554,
#   522,
#   7,
#   740,
#   2,
#   375,
#   38,
#   2,
#   21,
#   33,
#   24,
#   52,
#   232,
#   67,
#   6556,
#   2905,
#   63,
#   5,
#   1871,
#   52,
#   25,
#   514,
#   12,
#   26,
#   110,
#   167,
#   17,
#   4,
#   624,
#   6557,
#   7,
#   451,
#   274,
#   24,
#   21,
#   94,
#   12,
#   335,
#   4,
#   54,
#   2,
#   419,
#   18,
#   63,
#   33,
#   24,
#   56,
#   1202,
#   24,
#   421,
#   18,
#   1757,
#   24,
#   4831,
#   222,
#   2,
#   418,
#   4,
#   555,
#   124,
#   13,
#   102,
#   5,
#   555,
#   2,
#   104,
#   6558,
#   2600,
#   2150,
#   244,
#   64,
#   4,
#   1020,
#   625,
#   2151,
#   204,
#   20,
#   4,
#   2601,
#   1203,
#   13,
#   2602,
#   124],
#  [34,
#   41,
#   1383,
#   2,
#   288,
#   9,
#   196,
#   5,
#   3900,
#   326,
#   2351,
#   237,
#   139,
#   10,
#   23,
#   52,
#   1997,
#   2152,
#   29,
#   21,
#   34,
#   1095,
#   7,
#   698,
#   928,
#   45,
#   3313,
#   7,
#   351,
#   75,
#   26,
#   10,
#   1,
#   168,
#   23,
#   3314,
#   8,
#   135,
#   12,
#   8,
#   189,
#   161,
#   92,
#   75,
#   30,
#   10,
#   1,
#   194,
#   31,
#   1,
#   122,
#   21,
#   1021,
#   94,
#   3,
#   11,
#   3315,
#   8,
#   10,
#   1,
#   375,
#   77,
#   3,
#   46,
#   10,
#   90,
#   5,
#   280,
#   237,
#   1058,
#   34,
#   110,
#   41,
#   1998,
#   506,
#   323,
#   134,
#   683,
#   188,
#   10,
#   34,
#   87,
#   165,
#   35,
#   636,
#   366,
#   3,
#   1,
#   4832,
#   3,
#   14,
#   2603,
#   233,
#   233,
#   188,
#   158,
#   54,
#   1,
#   684,
#   38,
#   6,
#   4833,
#   1489,
#   6,
#   6559,
#   1096,
#   546,
#   23,
#   336,
#   11,
#   36,
#   3901,
#   3,
#   217,
#   11,
#   36,
#   3316,
#   2,
#   1169,
#   643,
#   4,
#   346,
#   173,
#   23,
#   289,
#   662,
#   15,
#   1998,
#   506],
#  [19,
#   111,
#   2604,
#   8,
#   77,
#   9,
#   89,
#   19,
#   111,
#   3317,
#   572,
#   2,
#   44,
#   2,
#   8,
#   462,
#   1,
#   111,
#   155,
#   2,
#   39,
#   3,
#   1,
#   149,
#   49,
#   324,
#   98,
#   1,
#   37,
#   71,
#   226,
#   2605,
#   39,
#   20,
#   350,
#   1097,
#   17,
#   19,
#   111,
#   3317,
#   572,
#   2,
#   44,
#   2,
#   8],
#  [1,
#   14,
#   76,
#   138,
#   5,
#   199,
#   54,
#   98,
#   104,
#   2906,
#   153,
#   452,
#   5,
#   339,
#   3,
#   1384,
#   9,
#   4,
#   3318,
#   7,
#   4,
#   182,
#   280,
#   91,
#   123,
#   104,
#   2906,
#   1,
#   16,
#   41,
#   105,
#   3319,
#   3,
#   4834,
#   68,
#   7,
#   6,
#   4834,
#   190,
#   2,
#   25,
#   68,
#   7,
#   62,
#   220,
#   103,
#   4,
#   184,
#   1259,
#   663,
#   1320,
#   151,
#   166,
#   1,
#   87,
#   490,
#   2,
#   161,
#   411,
#   1490,
#   38,
#   2,
#   4,
#   2606,
#   2352,
#   29,
#   123,
#   11,
#   14,
#   3320,
#   30,
#   6560,
#   7,
#   4,
#   382,
#   644,
#   366,
#   286,
#   8,
#   3,
#   6,
#   357,
#   16,
#   4835,
#   98,
#   182,
#   280,
#   91,
#   7,
#   69,
#   506],
#  [138,
#   83,
#   1,
#   16,
#   47,
#   9,
#   68,
#   6561,
#   1130,
#   2907,
#   5,
#   664,
#   7,
#   188,
#   6,
#   89,
#   55,
#   47,
#   32,
#   1758,
#   3,
#   71,
#   41,
#   2,
#   3902,
#   101,
#   5,
#   136,
#   188,
#   27,
#   5,
#   6562,
#   3,
#   16,
#   110,
#   41,
#   1321,
#   3903,
#   1872,
#   699,
#   741,
#   149,
#   41,
#   57,
#   357,
#   1750,
#   1260,
#   6563,
#   15,
#   167,
#   17,
#   111,
#   41,
#   2,
#   2908,
#   1580,
#   4836,
#   43,
#   2607],
#  [15,
#   5,
#   1999,
#   6564,
#   3,
#   418,
#   1491,
#   9,
#   5,
#   6565,
#   6566,
#   10,
#   3904,
#   5,
#   6567,
#   6568,
#   6569,
#   15,
#   6,
#   2909,
#   138,
#   4837,
#   10,
#   50,
#   87,
#   4,
#   209,
#   36,
#   4,
#   907,
#   1,
#   1661,
#   795,
#   9,
#   4,
#   2910,
#   9,
#   4,
#   174,
#   1,
#   6570,
#   6,
#   150,
#   7,
#   6571,
#   3,
#   60,
#   6572,
#   1,
#   53,
#   25,
#   9,
#   4,
#   477,
#   75,
#   4,
#   3905,
#   7,
#   780,
#   17,
#   1,
#   51,
#   26,
#   2911],
#  [2353,
#   2,
#   5,
#   523,
#   48,
#   244,
#   3,
#   202,
#   3321,
#   781,
#   1758,
#   2903,
#   109,
#   119,
#   478,
#   3,
#   5,
#   4838,
#   988,
#   7,
#   2000,
#   161,
#   2903,
#   2354,
#   2912,
#   723,
#   2,
#   2608,
#   17,
#   146,
#   580,
#   255,
#   106,
#   36,
#   13,
#   228,
#   6573,
#   10,
#   34,
#   143,
#   626,
#   20,
#   72,
#   311,
#   12,
#   1204,
#   7,
#   547,
#   273,
#   6574,
#   3,
#   2001,
#   7,
#   296,
#   287,
#   250,
#   507,
#   2,
#   314,
#   17,
#   207,
#   26,
#   3906,
#   1436,
#   2,
#   4,
#   796,
#   2002,
#   33,
#   34,
#   65,
#   2153,
#   2,
#   25,
#   1662,
#   3907,
#   34,
#   16,
#   2,
#   67,
#   2154,
#   42,
#   58,
#   284,
#   26,
#   181,
#   516,
#   1437],
#  [33,
#   135,
#   481,
#   321,
#   833,
#   1,
#   65,
#   2,
#   4839,
#   2,
#   1862,
#   3,
#   5,
#   133,
#   7,
#   4,
#   54,
#   27,
#   26,
#   185,
#   2,
#   37,
#   11,
#   35,
#   7,
#   3908,
#   86,
#   1,
#   217,
#   2,
#   25,
#   5,
#   79,
#   3909,
#   162,
#   3,
#   1,
#   412,
#   27,
#   111,
#   263,
#   17,
#   64,
#   27,
#   4840,
#   2,
#   501,
#   3,
#   1,
#   56,
#   65,
#   2,
#   439,
#   57,
#   908,
#   562,
#   14,
#   1,
#   545,
#   227,
#   10,
#   852,
#   31,
#   108,
#   57,
#   545,
#   162,
#   52,
#   180,
#   1,
#   49,
#   31,
#   1,
#   16,
#   4,
#   398,
#   7,
#   191],
#  [1,
#   59,
#   187,
#   46,
#   40,
#   2,
#   37,
#   28,
#   18,
#   3,
#   95,
#   682,
#   33,
#   95,
#   63,
#   185,
#   2,
#   44,
#   90,
#   18,
#   363,
#   5,
#   853,
#   361,
#   6575,
#   11,
#   9,
#   8,
#   36,
#   5,
#   645,
#   3,
#   212,
#   47,
#   1205,
#   11,
#   12,
#   21,
#   163,
#   10,
#   11,
#   307,
#   31,
#   497,
#   1759,
#   207,
#   6576,
#   21,
#   6577,
#   15,
#   8,
#   10,
#   302,
#   1165,
#   37,
#   94,
#   129,
#   1,
#   113,
#   68,
#   67,
#   33,
#   125,
#   53,
#   809,
#   68,
#   49,
#   443],
#  [1385,
#   55,
#   47,
#   61,
#   7,
#   4,
#   425,
#   151,
#   9,
#   5,
#   163,
#   54,
#   6,
#   208,
#   14,
#   9,
#   5,
#   236,
#   1438,
#   3,
#   55,
#   69,
#   299,
#   60,
#   291,
#   156,
#   2,
#   83,
#   5,
#   136,
#   201,
#   372,
#   6,
#   1322,
#   880,
#   3,
#   1,
#   137,
#   63,
#   16,
#   222,
#   175,
#   2,
#   3322,
#   4,
#   2913,
#   1,
#   1386,
#   139,
#   2,
#   25,
#   15,
#   6,
#   119,
#   3,
#   2,
#   643,
#   6,
#   208,
#   280,
#   293,
#   2,
#   4,
#   2914,
#   1,
#   637,
#   5,
#   2609,
#   20,
#   1261,
#   3,
#   64,
#   175,
#   13,
#   2155],
#  [515,
#   21,
#   9,
#   123,
#   1568,
#   16,
#   30,
#   100,
#   35,
#   7,
#   57,
#   3910,
#   121,
#   141,
#   34,
#   109,
#   1572,
#   2,
#   44,
#   685,
#   219,
#   121,
#   17,
#   11,
#   122,
#   26,
#   83,
#   35,
#   11,
#   430,
#   6578,
#   3,
#   34,
#   16,
#   359,
#   20,
#   9,
#   89,
#   161,
#   92,
#   446,
#   123,
#   4841,
#   1,
#   16,
#   47,
#   452,
#   18,
#   353],
#  [102,
#   4,
#   1760,
#   3323,
#   7,
#   1760,
#   45,
#   4,
#   54,
#   95,
#   21,
#   231,
#   1,
#   347,
#   18,
#   257,
#   36,
#   160,
#   36,
#   6,
#   358,
#   373,
#   420,
#   8,
#   95,
#   5,
#   4842,
#   86,
#   13,
#   601],
#  [27,
#   30,
#   2355,
#   176,
#   85,
#   18,
#   3324,
#   6579,
#   2,
#   67,
#   1,
#   49,
#   21,
#   6580,
#   158,
#   54,
#   1,
#   243,
#   62,
#   782,
#   31,
#   142,
#   260,
#   2356,
#   40,
#   27,
#   695,
#   15,
#   3,
#   1,
#   56,
#   16,
#   2,
#   1761,
#   73,
#   7,
#   6,
#   296,
#   1206,
#   1581,
#   1323,
#   638,
#   4843,
#   33,
#   24,
#   53,
#   563,
#   419,
#   144,
#   3325,
#   3,
#   56,
#   248,
#   38,
#   178,
#   24,
#   204,
#   142,
#   74,
#   1873,
#   24,
#   4,
#   118,
#   24,
#   810,
#   33,
#   1,
#   53,
#   37,
#   18,
#   1,
#   3326,
#   24,
#   53],
#  [1,
#   49,
#   31,
#   27,
#   159,
#   2,
#   346,
#   6,
#   277,
#   197,
#   27,
#   4844,
#   115,
#   92,
#   10,
#   5,
#   162,
#   52,
#   3327,
#   1582,
#   15,
#   17,
#   27,
#   26,
#   452,
#   4,
#   92,
#   27,
#   2156,
#   32,
#   29,
#   262,
#   1,
#   37,
#   3,
#   4,
#   2915,
#   13,
#   30,
#   2610,
#   4,
#   92,
#   58,
#   65,
#   35,
#   7,
#   8,
#   1,
#   49,
#   31,
#   4,
#   2915,
#   13,
#   723,
#   3,
#   1,
#   56,
#   225,
#   5,
#   133,
#   7,
#   54,
#   581,
#   11,
#   1,
#   479,
#   4845,
#   43,
#   27,
#   32,
#   83,
#   1,
#   49,
#   31,
#   1,
#   59,
#   626,
#   9,
#   20,
#   5,
#   3328],
#  [1,
#   51,
#   59,
#   80,
#   31,
#   82,
#   50,
#   69,
#   129,
#   742,
#   58,
#   50,
#   45,
#   30,
#   646,
#   2,
#   929,
#   1,
#   93,
#   1,
#   52,
#   627,
#   25,
#   308,
#   134,
#   370,
#   15,
#   81,
#   406,
#   127,
#   55,
#   125,
#   170,
#   194,
#   31,
#   18,
#   122,
#   88,
#   403,
#   211,
#   472],
#  [24,
#   53,
#   120,
#   4,
#   1663,
#   20,
#   6,
#   1256,
#   182,
#   157,
#   244,
#   3,
#   1762,
#   5,
#   555,
#   2,
#   4,
#   1262,
#   6581,
#   244,
#   21,
#   27,
#   1439,
#   24,
#   124,
#   476,
#   1439,
#   24,
#   33,
#   434,
#   125,
#   35,
#   82,
#   74,
#   52,
#   25,
#   263,
#   222,
#   2,
#   248,
#   8,
#   5,
#   497,
#   679,
#   2,
#   958,
#   6,
#   613,
#   38,
#   3,
#   1098,
#   6,
#   1170,
#   52,
#   24,
#   232,
#   1171,
#   724,
#   8,
#   68,
#   1099,
#   2157,
#   1324,
#   6,
#   1387,
#   244,
#   27,
#   476,
#   9,
#   3911,
#   113,
#   7,
#   67,
#   157,
#   124,
#   3,
#   1,
#   56,
#   46,
#   116,
#   170,
#   2,
#   647,
#   105,
#   134,
#   4,
#   78,
#   7,
#   4,
#   811,
#   263,
#   2916],
#  [122,
#   1,
#   959,
#   6,
#   264,
#   50,
#   2917,
#   1,
#   56,
#   46,
#   33,
#   18,
#   13,
#   381,
#   12,
#   2917,
#   78,
#   2,
#   1325,
#   639,
#   1,
#   179,
#   73,
#   27,
#   835,
#   7,
#   84,
#   320,
#   58,
#   179,
#   8,
#   27,
#   5,
#   1440,
#   31,
#   5,
#   779,
#   3,
#   44,
#   90,
#   11,
#   6,
#   264,
#   264,
#   122,
#   26,
#   1325,
#   73,
#   18,
#   118,
#   725,
#   562,
#   757,
#   42,
#   58,
#   1,
#   409,
#   592,
#   29,
#   1093,
#   91,
#   166,
#   109,
#   354,
#   43,
#   58,
#   109,
#   6,
#   495,
#   42,
#   58,
#   126,
#   58,
#   242,
#   665,
#   20,
#   144,
#   192,
#   32,
#   930,
#   3,
#   10,
#   58,
#   204,
#   11,
#   2611,
#   27,
#   881,
#   3,
#   58,
#   204,
#   11,
#   2611,
#   84,
#   154,
#   8],
#  [24,
#   50,
#   84,
#   1441,
#   2,
#   1022,
#   9,
#   5,
#   638,
#   523,
#   12,
#   6582,
#   6583,
#   6584,
#   32,
#   1874,
#   3912,
#   666,
#   4,
#   1875,
#   7,
#   4,
#   587,
#   523,
#   13,
#   2,
#   4846,
#   4,
#   3329,
#   7,
#   342,
#   6585,
#   9,
#   283,
#   15,
#   5,
#   726,
#   3,
#   6586,
#   296,
#   1206,
#   4847,
#   3,
#   60,
#   11,
#   6587,
#   2,
#   342,
#   2158,
#   3,
#   89,
#   4848,
#   4,
#   638,
#   13,
#   2918,
#   2,
#   2919,
#   4,
#   3330,
#   15,
#   625,
#   28,
#   2920,
#   10,
#   97,
#   1487,
#   89,
#   4848,
#   9,
#   2357,
#   498,
#   15,
#   57,
#   4847,
#   6588,
#   54,
#   12,
#   4,
#   371,
#   13,
#   2921,
#   683,
#   1442,
#   440,
#   2159,
#   50,
#   110,
#   743,
#   2,
#   1022,
#   238,
#   9,
#   4,
#   587,
#   523],
#  [18,
#   14,
#   5,
#   6589,
#   6590,
#   3,
#   63,
#   197,
#   1,
#   41,
#   47,
#   114,
#   6,
#   261,
#   2,
#   87,
#   243,
#   5,
#   931,
#   32,
#   4,
#   1317,
#   11,
#   378,
#   2922,
#   6,
#   314,
#   10,
#   82,
#   284,
#   25,
#   108,
#   225,
#   9,
#   18,
#   931,
#   29,
#   10,
#   1,
#   14,
#   84,
#   1207,
#   2,
#   25,
#   72,
#   4849,
#   98,
#   1,
#   153,
#   6591,
#   20,
#   10,
#   931,
#   1,
#   194,
#   45,
#   4,
#   989,
#   447,
#   8,
#   3,
#   194,
#   644,
#   19,
#   126,
#   212,
#   2923,
#   57,
#   2924,
#   12,
#   167,
#   112,
#   1,
#   168,
#   1,
#   14,
#   84,
#   1763,
#   77,
#   32,
#   139,
#   1,
#   187,
#   260,
#   312,
#   4,
#   1100,
#   139,
#   9,
#   4,
#   2924,
#   34,
#   1388,
#   38,
#   32,
#   62,
#   517,
#   2358,
#   3,
#   19,
#   126,
#   181,
#   648,
#   1,
#   46,
#   1664,
#   3331,
#   1,
#   16,
#   1876,
#   1,
#   168,
#   744,
#   1876,
#   52,
#   25,
#   5,
#   129,
#   299,
#   98,
#   4,
#   989,
#   21,
#   1,
#   1443,
#   39,
#   648],
#  [17,
#   75,
#   47,
#   182,
#   6592,
#   18,
#   54,
#   34,
#   137,
#   854,
#   12,
#   960,
#   29,
#   169,
#   121,
#   27,
#   882,
#   355,
#   416,
#   32,
#   4,
#   277,
#   26,
#   416,
#   32,
#   39,
#   3,
#   4,
#   425,
#   241,
#   13,
#   26,
#   84,
#   185,
#   2,
#   155,
#   29,
#   63,
#   46,
#   1172,
#   76,
#   20,
#   34,
#   137,
#   548,
#   132,
#   18,
#   21,
#   268,
#   26,
#   416,
#   32,
#   8],
#  [383,
#   18,
#   76,
#   2,
#   25,
#   623,
#   163,
#   1,
#   16,
#   5,
#   133,
#   2,
#   180,
#   278,
#   247,
#   120,
#   1492,
#   11,
#   14,
#   1023,
#   38,
#   3,
#   152,
#   61,
#   986,
#   34,
#   109,
#   240,
#   3,
#   19,
#   14,
#   84,
#   72,
#   2925,
#   134,
#   19,
#   55,
#   9,
#   91,
#   4,
#   219,
#   268,
#   783,
#   32,
#   8,
#   3,
#   987,
#   8,
#   5,
#   2612,
#   1,
#   44,
#   11,
#   1,
#   437,
#   39,
#   1,
#   49,
#   21,
#   3913,
#   3,
#   1326,
#   15,
#   101,
#   17,
#   1,
#   708,
#   65,
#   2,
#   463,
#   6,
#   89,
#   15,
#   69,
#   61,
#   170],
#  [23,
#   14,
#   3332,
#   3,
#   58,
#   325,
#   9,
#   5,
#   496,
#   19,
#   14,
#   9,
#   4,
#   932,
#   2926,
#   23,
#   14,
#   9,
#   4,
#   296,
#   496,
#   23,
#   14,
#   930,
#   3,
#   19,
#   4850,
#   4851,
#   22,
#   990,
#   883,
#   4,
#   678,
#   23,
#   722,
#   100,
#   1583,
#   15,
#   8,
#   3,
#   19,
#   685,
#   22,
#   32,
#   112,
#   195,
#   4,
#   1764,
#   6593,
#   144,
#   760,
#   7,
#   4,
#   591,
#   1,
#   14,
#   1129,
#   6594,
#   280,
#   151,
#   3,
#   198,
#   303,
#   112,
#   9,
#   6595,
#   14,
#   79,
#   2927,
#   1,
#   637,
#   540,
#   151,
#   9,
#   57,
#   6596,
#   3,
#   41,
#   345,
#   855,
#   17,
#   665,
#   3,
#   16,
#   26,
#   41,
#   287,
#   478],
#  [3,
#   11,
#   281,
#   8,
#   72,
#   341,
#   112,
#   1493,
#   8,
#   2,
#   3333,
#   38,
#   72,
#   75,
#   156,
#   324,
#   197,
#   1,
#   168,
#   1,
#   97,
#   680,
#   11,
#   152,
#   18,
#   55,
#   47,
#   57,
#   2928,
#   508,
#   12,
#   28,
#   5,
#   121,
#   29,
#   21,
#   3,
#   11,
#   55,
#   87,
#   47,
#   18,
#   160,
#   17,
#   804,
#   75,
#   156,
#   2,
#   4,
#   195,
#   116,
#   1,
#   117,
#   63,
#   155,
#   2,
#   6,
#   192,
#   261,
#   252,
#   1059,
#   35,
#   90,
#   18,
#   407,
#   23,
#   270,
#   77,
#   9,
#   594,
#   48,
#   5,
#   79,
#   163,
#   484,
#   121,
#   1658,
#   286,
#   3,
#   1,
#   41,
#   2,
#   70,
#   2,
#   1060,
#   15,
#   22,
#   42,
#   309,
#   40,
#   551,
#   6597,
#   2,
#   37,
#   3,
#   1,
#   41,
#   2,
#   812,
#   82,
#   3,
#   210,
#   3,
#   107,
#   408,
#   155,
#   15,
#   6,
#   390,
#   4,
#   436,
#   1101,
#   174,
#   255,
#   341,
#   36,
#   613,
#   1,
#   46,
#   58,
#   628],
#  [17,
#   27,
#   59,
#   59,
#   315,
#   7,
#   906,
#   6598,
#   3,
#   1494,
#   1130,
#   21,
#   1,
#   14,
#   9,
#   4,
#   1584,
#   2613,
#   3,
#   471,
#   18,
#   320,
#   1444,
#   393,
#   12,
#   319,
#   3,
#   175,
#   1,
#   149,
#   67,
#   320,
#   78,
#   33,
#   1,
#   16,
#   472,
#   9,
#   6,
#   2614,
#   1,
#   1327,
#   38,
#   2,
#   22,
#   336,
#   35,
#   6,
#   2614,
#   3,
#   1388,
#   35,
#   18,
#   6599,
#   1328,
#   2,
#   248,
#   22,
#   23,
#   14,
#   599,
#   220,
#   21,
#   23,
#   289,
#   9,
#   5,
#   1131,
#   474,
#   287],
#  [104,
#   502,
#   6600,
#   55,
#   47,
#   498,
#   15,
#   6601,
#   3,
#   13,
#   64,
#   9,
#   4,
#   496,
#   2,
#   6602,
#   62,
#   780,
#   2615,
#   1571,
#   19,
#   332,
#   2,
#   25,
#   189,
#   146,
#   3,
#   19,
#   66,
#   25,
#   139,
#   15,
#   167,
#   489,
#   813,
#   62,
#   836,
#   13,
#   1263,
#   222,
#   10,
#   34,
#   30,
#   117,
#   1024,
#   11,
#   20,
#   104,
#   192,
#   556,
#   15,
#   104,
#   1445,
#   1099,
#   277,
#   470,
#   84,
#   3334,
#   48,
#   104,
#   139,
#   489,
#   3,
#   159,
#   2,
#   204,
#   5,
#   200,
#   15,
#   18,
#   836,
#   13,
#   30,
#   140,
#   94,
#   12,
#   167,
#   85,
#   2359,
#   2,
#   67,
#   167,
#   15,
#   4,
#   836,
#   34,
#   614,
#   38,
#   5,
#   1387,
#   244],
#  [6603,
#   184,
#   4852,
#   615,
#   75,
#   43,
#   108,
#   1493,
#   6604,
#   363,
#   9,
#   4,
#   162,
#   6605,
#   280,
#   359,
#   214,
#   72,
#   1877,
#   2,
#   5,
#   1061,
#   522,
#   17,
#   11,
#   13,
#   86,
#   1877,
#   6606,
#   3,
#   269,
#   853,
#   595],
#  [1,
#   137,
#   37,
#   135,
#   316,
#   2616,
#   374,
#   856,
#   262,
#   70,
#   2,
#   83,
#   3,
#   63,
#   99,
#   1,
#   1488,
#   5,
#   96,
#   42,
#   1,
#   30,
#   367,
#   370,
#   15,
#   4,
#   595,
#   184,
#   1446,
#   44,
#   991,
#   2,
#   179,
#   24,
#   58,
#   122,
#   667,
#   216,
#   316,
#   144,
#   374,
#   3,
#   82,
#   14,
#   5,
#   54,
#   43,
#   1,
#   961,
#   335,
#   5,
#   374,
#   140,
#   17,
#   64,
#   11,
#   332,
#   31,
#   158,
#   54,
#   1,
#   16,
#   5,
#   374,
#   29,
#   5,
#   96,
#   115,
#   48,
#   83,
#   11,
#   281,
#   4,
#   595,
#   324],
#  [1,
#   661,
#   244,
#   112,
#   6607,
#   2,
#   179,
#   4,
#   992,
#   1102,
#   7,
#   78,
#   883,
#   4,
#   678,
#   9,
#   560,
#   2,
#   2003,
#   5,
#   2360,
#   837,
#   7,
#   61,
#   228,
#   3,
#   2617,
#   933,
#   9,
#   4853,
#   7,
#   285,
#   84,
#   296,
#   287,
#   1569,
#   237,
#   470,
#   784,
#   2,
#   709,
#   28,
#   78,
#   15,
#   296,
#   2618,
#   2,
#   1878,
#   1569,
#   33,
#   551,
#   582,
#   9,
#   84,
#   2619,
#   12,
#   5,
#   391,
#   232,
#   694,
#   8,
#   5,
#   2004,
#   1,
#   16,
#   1208,
#   101,
#   21,
#   1,
#   53,
#   4854,
#   24,
#   4,
#   1665,
#   66,
#   25,
#   1209,
#   15,
#   4,
#   4855,
#   11,
#   2160,
#   884,
#   34,
#   50,
#   26,
#   189,
#   1666,
#   2361,
#   32,
#   18,
#   54,
#   21,
#   88,
#   431,
#   453,
#   52,
#   25,
#   3335,
#   9,
#   4,
#   391],
#  [1,
#   49,
#   31,
#   1,
#   66,
#   87,
#   564,
#   6,
#   192,
#   2929,
#   127,
#   198,
#   1,
#   343,
#   347,
#   84,
#   18,
#   162,
#   1,
#   347,
#   84,
#   5,
#   993,
#   1,
#   52,
#   87,
#   2005,
#   125,
#   170,
#   9,
#   6,
#   277,
#   17,
#   1,
#   368,
#   1025,
#   145,
#   2,
#   120,
#   101,
#   36,
#   142,
#   74,
#   14,
#   545,
#   6,
#   2930,
#   545,
#   6,
#   1322,
#   22,
#   436,
#   928,
#   3,
#   1,
#   149,
#   194,
#   31,
#   42,
#   7,
#   10,
#   1,
#   52,
#   149,
#   25,
#   20,
#   4,
#   6608],
#  [2931,
#   6609,
#   6610,
#   2161,
#   2931,
#   1103,
#   6611,
#   1264,
#   4856,
#   443,
#   6612,
#   2931,
#   454,
#   2,
#   104,
#   4857,
#   184,
#   2006,
#   78,
#   15,
#   3914,
#   29,
#   74,
#   50,
#   3915,
#   29,
#   6613,
#   4858,
#   161,
#   50,
#   78,
#   74,
#   455,
#   573,
#   1389,
#   454,
#   3,
#   455,
#   44,
#   906,
#   2157,
#   4,
#   1264,
#   3916,
#   138,
#   5,
#   2932,
#   2162,
#   7,
#   72,
#   134,
#   683,
#   1867,
#   6614,
#   3,
#   198,
#   4859,
#   2931,
#   4812,
#   883,
#   4,
#   3336,
#   1390,
#   2,
#   1879,
#   12,
#   1103,
#   6615,
#   934,
#   988,
#   3917,
#   797,
#   2,
#   279,
#   12,
#   2931,
#   250,
#   3,
#   4860,
#   16,
#   5,
#   2362,
#   1132,
#   29],
#  [27,
#   258,
#   745,
#   3,
#   16,
#   5,
#   6616,
#   1667,
#   12,
#   814,
#   17,
#   3918,
#   4,
#   2933,
#   481,
#   1026,
#   30,
#   962,
#   4861,
#   26,
#   222,
#   319,
#   29,
#   4,
#   2934,
#   10,
#   507,
#   15,
#   11,
#   1210,
#   2,
#   160,
#   3919,
#   184,
#   3920,
#   246,
#   14,
#   17,
#   5,
#   6617,
#   1062,
#   43,
#   4,
#   174,
#   54,
#   3921,
#   50,
#   111,
#   9,
#   4,
#   2935,
#   6618,
#   24,
#   30,
#   6619,
#   2363,
#   3,
#   6620,
#   3922,
#   88,
#   2163,
#   43,
#   202,
#   4862,
#   3923,
#   3,
#   1765],
#  [1,
#   30,
#   100,
#   35,
#   7,
#   5,
#   696,
#   121,
#   681,
#   20,
#   17,
#   294,
#   115,
#   141,
#   4,
#   147,
#   1880,
#   34,
#   41,
#   19,
#   14,
#   588,
#   35,
#   4,
#   174,
#   132,
#   19,
#   41,
#   4863,
#   8,
#   741,
#   41,
#   5,
#   1585,
#   141,
#   17,
#   681,
#   1133,
#   19,
#   708,
#   226,
#   2,
#   150,
#   8,
#   36,
#   94,
#   36,
#   532,
#   17,
#   52,
#   44,
#   644,
#   3,
#   25,
#   2592,
#   417],
#  [756,
#   230,
#   1,
#   113,
#   5,
#   200,
#   2,
#   1329,
#   3,
#   200,
#   6,
#   403,
#   42,
#   1,
#   56,
#   46,
#   40,
#   2,
#   37,
#   282,
#   18,
#   1766,
#   148,
#   1063,
#   5,
#   6621,
#   15,
#   6,
#   649,
#   3,
#   68,
#   103,
#   1,
#   275,
#   35,
#   6,
#   649,
#   1579,
#   449,
#   54,
#   388,
#   147,
#   121,
#   34,
#   376,
#   10,
#   1,
#   52,
#   1586,
#   39,
#   18,
#   121,
#   20,
#   62,
#   4864,
#   1064,
#   15,
#   62,
#   103,
#   62,
#   299,
#   18,
#   289,
#   532,
#   9,
#   4,
#   253,
#   29,
#   21,
#   19,
#   114,
#   8,
#   42,
#   62,
#   103,
#   137,
#   65,
#   2,
#   491,
#   5,
#   3337,
#   17,
#   70,
#   20,
#   5,
#   1495,
#   693,
#   4864,
#   1064],
#  [212,
#   47,
#   602,
#   1767,
#   20,
#   32,
#   174,
#   242,
#   9,
#   4,
#   1587,
#   2164,
#   3,
#   6,
#   1265,
#   4,
#   363,
#   13,
#   242,
#   474,
#   3,
#   509,
#   95,
#   21,
#   3338,
#   32,
#   83,
#   3,
#   32,
#   139,
#   1,
#   49,
#   31,
#   95,
#   452,
#   92,
#   1588,
#   3,
#   172,
#   4865,
#   7,
#   322,
#   2007,
#   138,
#   8,
#   45,
#   96,
#   95,
#   59,
#   30,
#   795,
#   18,
#   1021,
#   806,
#   157,
#   64,
#   3,
#   360,
#   2,
#   709,
#   11,
#   35,
#   1,
#   409],
#  [45,
#   7,
#   161,
#   92,
#   1,
#   93,
#   3339,
#   2,
#   18,
#   84,
#   5,
#   323,
#   853,
#   361,
#   134,
#   4,
#   130,
#   1065,
#   30,
#   132,
#   4,
#   497,
#   1065,
#   23,
#   263,
#   7,
#   6622,
#   581,
#   104,
#   130,
#   645,
#   9,
#   4,
#   903,
#   112,
#   34,
#   372,
#   1134,
#   441,
#   22,
#   6623,
#   6624,
#   4866,
#   244,
#   23,
#   260,
#   41,
#   3924,
#   77,
#   1330,
#   3925,
#   534,
#   72,
#   20,
#   18,
#   372,
#   9,
#   4,
#   130,
#   1863,
#   36,
#   146,
#   3,
#   18,
#   14,
#   324,
#   1496,
#   22,
#   2,
#   113,
#   6625,
#   12,
#   4,
#   6626,
#   7,
#   4,
#   1863,
#   18,
#   13,
#   26,
#   5,
#   623,
#   6627,
#   218,
#   12,
#   5,
#   565,
#   2,
#   361,
#   244,
#   112,
#   2165,
#   6,
#   1331,
#   211,
#   4867,
#   6628,
#   2936,
#   803,
#   1589,
#   120,
#   510,
#   17,
#   12,
#   184,
#   929,
#   11,
#   6629,
#   1173,
#   785,
#   98,
#   4,
#   779,
#   13,
#   1129,
#   12,
#   6,
#   3926,
#   11,
#   378,
#   3,
#   23,
#   153,
#   452,
#   5,
#   6630,
#   1135,
#   474,
#   339,
#   18,
#   262,
#   432,
#   262,
#   378],
#  [3927,
#   56,
#   250,
#   28,
#   83,
#   293,
#   24,
#   46,
#   362,
#   333,
#   379,
#   1590,
#   815,
#   104,
#   6631,
#   12,
#   4,
#   136,
#   293,
#   400,
#   62,
#   431,
#   6632,
#   246,
#   3,
#   83,
#   21,
#   470,
#   189,
#   18,
#   27,
#   4868,
#   20,
#   57,
#   6633,
#   1262,
#   189,
#   6634,
#   54,
#   268,
#   20,
#   384,
#   15,
#   779,
#   963,
#   4,
#   2937,
#   6635,
#   1174,
#   19,
#   2364,
#   710,
#   3,
#   779,
#   257,
#   2364,
#   106,
#   3340,
#   400,
#   6636,
#   3,
#   1066],
#  [173,
#   52,
#   24,
#   180,
#   10,
#   2,
#   8,
#   3,
#   404,
#   518,
#   3928,
#   19,
#   2365,
#   20,
#   85,
#   724,
#   8,
#   4,
#   1881,
#   454,
#   12,
#   1018,
#   440,
#   3,
#   99,
#   507,
#   9,
#   4,
#   300,
#   3,
#   711,
#   8,
#   24,
#   56,
#   328,
#   8,
#   69,
#   61,
#   2356,
#   8,
#   1,
#   248,
#   38,
#   20,
#   171],
#  [23,
#   14,
#   317,
#   589,
#   1882,
#   1211,
#   98,
#   348,
#   32,
#   130,
#   17,
#   64,
#   23,
#   332,
#   2,
#   16,
#   359,
#   2,
#   5,
#   6637,
#   116,
#   291,
#   515,
#   15,
#   8,
#   1882,
#   1211,
#   36,
#   163,
#   36,
#   291,
#   82,
#   43,
#   11,
#   857,
#   36,
#   9,
#   1,
#   97,
#   2008,
#   15,
#   30,
#   22,
#   29,
#   43,
#   470,
#   242,
#   909,
#   35,
#   15,
#   4,
#   209,
#   103,
#   71,
#   226,
#   393,
#   22,
#   28,
#   11,
#   3,
#   1497,
#   837,
#   173,
#   23,
#   307,
#   18,
#   118,
#   28,
#   11,
#   17,
#   23,
#   117,
#   473,
#   2,
#   1668,
#   11,
#   2594,
#   340,
#   10,
#   75,
#   5,
#   1883,
#   80,
#   10,
#   23,
#   404,
#   10,
#   3341,
#   2166,
#   22,
#   3,
#   1391,
#   22,
#   86,
#   23,
#   520,
#   79,
#   3342,
#   304,
#   28,
#   11,
#   3,
#   14,
#   257,
#   32,
#   4,
#   6638,
#   7,
#   686,
#   340,
#   10,
#   23,
#   2366,
#   23,
#   394,
#   173,
#   11,
#   2166,
#   22,
#   21,
#   94,
#   17,
#   11,
#   227,
#   3,
#   23,
#   117,
#   67,
#   11,
#   69,
#   591,
#   60,
#   94,
#   23,
#   758,
#   28,
#   11,
#   29,
#   60,
#   94,
#   1,
#   210,
#   2,
#   816,
#   11,
#   2,
#   22,
#   1,
#   56,
#   46,
#   60,
#   2,
#   816,
#   18,
#   2,
#   22,
#   1,
#   56,
#   65,
#   2,
#   248,
#   38,
#   4,
#   1067,
#   7,
#   1882,
#   1211,
#   15,
#   103,
#   17,
#   1,
#   56,
#   65,
#   2,
#   374,
#   38,
#   15,
#   22,
#   90,
#   108,
#   31,
#   18,
#   42,
#   1,
#   150,
#   22],
#  [316,
#   4,
#   1863,
#   3,
#   98,
#   4,
#   853,
#   1065,
#   7,
#   104,
#   130,
#   369,
#   9,
#   3343,
#   398,
#   153,
#   2,
#   6639,
#   1136,
#   1137,
#   7,
#   271,
#   68,
#   4869,
#   616,
#   3,
#   6640,
#   416,
#   3344,
#   885,
#   9,
#   82,
#   34,
#   2167,
#   20,
#   5,
#   79,
#   2620,
#   1332,
#   2938,
#   2621,
#   7,
#   296,
#   287,
#   858,
#   10,
#   6641,
#   398,
#   34,
#   41,
#   104,
#   497,
#   369,
#   9,
#   2367,
#   98,
#   112,
#   57,
#   1768,
#   1210,
#   2,
#   4,
#   4870,
#   7,
#   5,
#   3929,
#   3,
#   4871,
#   6642,
#   4872,
#   668,
#   4,
#   398,
#   48,
#   18,
#   16,
#   47,
#   156,
#   324,
#   123,
#   99,
#   3,
#   5,
#   129,
#   3930,
#   7,
#   54,
#   48,
#   2367,
#   178,
#   64,
#   55,
#   47,
#   4873,
#   1769,
#   76,
#   20,
#   401,
#   2,
#   4874,
#   15,
#   5,
#   169,
#   1027,
#   3,
#   3931,
#   283,
#   398,
#   1498,
#   2168,
#   41,
#   5,
#   79,
#   745,
#   1266,
#   141,
#   15,
#   554,
#   1499,
#   3932],
#  [27,
#   466,
#   1,
#   16,
#   5,
#   780,
#   6643,
#   29,
#   108,
#   10,
#   404,
#   6644,
#   43,
#   1,
#   1392,
#   73,
#   1,
#   30,
#   65,
#   2,
#   25,
#   515,
#   3,
#   2,
#   16,
#   5,
#   129,
#   54,
#   20,
#   18,
#   1064,
#   17,
#   71,
#   47,
#   21,
#   35,
#   7,
#   11,
#   3,
#   27,
#   32,
#   6,
#   4875,
#   253,
#   157,
#   64,
#   27,
#   1068,
#   152,
#   3,
#   1,
#   49,
#   780,
#   6645,
#   45,
#   138,
#   6,
#   290,
#   3,
#   3933,
#   7,
#   780,
#   6646,
#   154,
#   6,
#   2169,
#   27,
#   518,
#   246,
#   3345,
#   3,
#   6647,
#   17,
#   27,
#   298,
#   2,
#   70,
#   2,
#   246,
#   3,
#   51,
#   9,
#   534,
#   27,
#   21,
#   298],
#  [1,
#   16,
#   191,
#   48,
#   6,
#   547,
#   273,
#   3,
#   18,
#   183,
#   55,
#   47,
#   59,
#   199,
#   59,
#   123,
#   247,
#   3346,
#   270,
#   35,
#   589,
#   4876,
#   3,
#   4,
#   4877,
#   7,
#   11,
#   235,
#   197,
#   14,
#   59,
#   199,
#   1,
#   181,
#   139,
#   2,
#   120,
#   6,
#   349,
#   1104,
#   6648,
#   1591,
#   3,
#   2939,
#   10,
#   247,
#   3346,
#   13,
#   5,
#   1068,
#   2612,
#   62,
#   700],
#  [3,
#   1,
#   56,
#   234,
#   12,
#   4,
#   786,
#   2,
#   4878,
#   8,
#   7,
#   45,
#   1500,
#   3,
#   107,
#   8,
#   49,
#   324,
#   1138,
#   4,
#   96,
#   4,
#   1175,
#   1,
#   210,
#   2,
#   25,
#   381,
#   1,
#   14,
#   1447,
#   20,
#   1267,
#   2170,
#   252,
#   6,
#   3347,
#   1669,
#   12,
#   18,
#   1393,
#   238,
#   1,
#   44,
#   2,
#   666,
#   3,
#   44,
#   2167,
#   17,
#   64,
#   27,
#   682,
#   33,
#   27,
#   76,
#   2,
#   25,
#   114,
#   4,
#   209,
#   218,
#   85,
#   5,
#   339,
#   82,
#   27,
#   26,
#   255,
#   12,
#   5,
#   1268,
#   30,
#   78,
#   74,
#   380,
#   6,
#   361,
#   29,
#   46,
#   40,
#   27,
#   304,
#   28,
#   27,
#   383,
#   33,
#   18,
#   332,
#   263,
#   7,
#   6649,
#   29,
#   2009,
#   6,
#   352,
#   50,
#   5,
#   305,
#   7,
#   5,
#   1069,
#   3,
#   27,
#   26,
#   224,
#   40,
#   2,
#   93,
#   274,
#   24,
#   12,
#   421,
#   45,
#   18,
#   6650],
#  [1,
#   394,
#   2368,
#   14,
#   3934,
#   1,
#   226,
#   2171,
#   38,
#   2,
#   6,
#   249,
#   3,
#   19,
#   126,
#   19,
#   603,
#   250,
#   33,
#   62,
#   583,
#   14,
#   5,
#   6651,
#   6652,
#   994,
#   52,
#   19,
#   250,
#   4879,
#   10,
#   583,
#   282,
#   1,
#   99,
#   41,
#   2,
#   854,
#   2,
#   4,
#   6653,
#   7,
#   6,
#   1884,
#   3,
#   179,
#   39,
#   28,
#   8,
#   1501,
#   84,
#   2368,
#   6,
#   249,
#   14,
#   9,
#   4,
#   77,
#   7,
#   4,
#   300,
#   3,
#   228,
#   406,
#   1,
#   41,
#   87,
#   325,
#   4880,
#   964,
#   219,
#   2,
#   39,
#   19,
#   223,
#   8,
#   33,
#   1,
#   41,
#   211,
#   41,
#   81,
#   2368,
#   4881],
#  [1,
#   521,
#   6,
#   290,
#   38,
#   3,
#   2940,
#   4,
#   1592,
#   1,
#   810,
#   1,
#   14,
#   79,
#   2622,
#   3,
#   1333,
#   4,
#   209,
#   23,
#   1028,
#   21,
#   1,
#   225,
#   22,
#   9,
#   22,
#   200,
#   23,
#   4882,
#   8,
#   12,
#   602,
#   6,
#   6654,
#   1593,
#   38,
#   9,
#   4,
#   3935,
#   300,
#   1,
#   270,
#   77,
#   2,
#   210,
#   20,
#   228,
#   6655,
#   3,
#   23,
#   481,
#   24,
#   97,
#   32,
#   337,
#   612,
#   73,
#   77,
#   314,
#   24,
#   1,
#   16,
#   5,
#   61,
#   121,
#   220,
#   9,
#   6,
#   6656],
#  [1,
#   46,
#   158,
#   54,
#   1,
#   16,
#   322,
#   467,
#   2,
#   1885,
#   101,
#   75,
#   30,
#   9,
#   6,
#   290,
#   17,
#   11,
#   1176,
#   43,
#   172,
#   92,
#   30,
#   107,
#   24,
#   49,
#   31,
#   407,
#   227,
#   125,
#   170,
#   44,
#   1139,
#   85,
#   598,
#   92,
#   31,
#   18,
#   27,
#   63,
#   30,
#   1334,
#   32,
#   101,
#   12,
#   64,
#   80,
#   757,
#   32,
#   6,
#   208,
#   31,
#   56,
#   24,
#   46,
#   26,
#   2,
#   179,
#   142,
#   15,
#   287,
#   86,
#   10,
#   58,
#   56,
#   375,
#   157,
#   2010],
#  [9,
#   1259,
#   91,
#   71,
#   628,
#   10,
#   1,
#   370,
#   15,
#   68,
#   269,
#   6657,
#   3936,
#   4883,
#   5,
#   133,
#   1138,
#   4,
#   96,
#   370,
#   15,
#   1760,
#   3,
#   16,
#   6658,
#   6659,
#   910,
#   262,
#   1,
#   16,
#   1502,
#   68,
#   263,
#   7,
#   3937,
#   10,
#   13,
#   6660,
#   18,
#   81,
#   67,
#   13,
#   574],
#  [9,
#   746,
#   377,
#   149,
#   20,
#   1435,
#   1,
#   727,
#   626,
#   20,
#   61,
#   218,
#   12,
#   140,
#   163,
#   3,
#   1,
#   373,
#   4884,
#   6,
#   2011,
#   3,
#   1,
#   93,
#   58,
#   93,
#   377,
#   255,
#   32,
#   73,
#   112,
#   377,
#   26,
#   18,
#   102,
#   165,
#   11,
#   72,
#   1494,
#   2,
#   155,
#   2,
#   73,
#   1,
#   47,
#   82,
#   12,
#   5,
#   237,
#   17,
#   377,
#   111,
#   79,
#   650,
#   154,
#   6,
#   2623,
#   3,
#   2624,
#   1,
#   46,
#   6,
#   1770,
#   3,
#   4,
#   3348,
#   82,
#   44,
#   650,
#   651,
#   154,
#   8,
#   804,
#   58,
#   413,
#   47,
#   304,
#   2,
#   8,
#   94,
#   29,
#   401,
#   38,
#   2,
#   8,
#   556,
#   4,
#   3348,
#   2,
#   234,
#   33,
#   1,
#   113,
#   67,
#   112,
#   58,
#   122,
#   132,
#   6,
#   86,
#   55,
#   593,
#   324,
#   3,
#   1,
#   329,
#   375,
#   72,
#   3349,
#   651,
#   134,
#   211,
#   21,
#   10,
#   173,
#   58,
#   16,
#   859,
#   223,
#   33,
#   1,
#   360,
#   67,
#   29,
#   126,
#   94,
#   2,
#   8,
#   4885,
#   462,
#   473,
#   72,
#   32,
#   2369,
#   15,
#   105,
#   78],
#  [27,
#   778,
#   210,
#   3,
#   44,
#   68,
#   246,
#   36,
#   75,
#   4,
#   849,
#   7,
#   4,
#   174,
#   124,
#   3,
#   1,
#   412,
#   1,
#   44,
#   138,
#   838,
#   15,
#   5,
#   728,
#   876,
#   31,
#   1,
#   149,
#   499,
#   12,
#   132,
#   1,
#   70,
#   2,
#   246,
#   1,
#   680,
#   10,
#   412,
#   3,
#   1,
#   46,
#   61,
#   96,
#   2012,
#   446,
#   26,
#   64,
#   17,
#   61,
#   96,
#   575,
#   274,
#   24,
#   45,
#   12,
#   88,
#   311,
#   3,
#   263,
#   1177,
#   75,
#   59,
#   432,
#   8,
#   44,
#   138,
#   235,
#   3,
#   2,
#   229,
#   588,
#   516,
#   69,
#   591,
#   60,
#   1448,
#   11,
#   332,
#   75,
#   111,
#   588,
#   516],
#  [1,
#   16,
#   5,
#   4886,
#   399,
#   6661,
#   3,
#   1,
#   347,
#   22,
#   1,
#   1497,
#   117,
#   816,
#   11,
#   1,
#   46,
#   75,
#   21,
#   2941,
#   17,
#   75,
#   30,
#   60,
#   11,
#   13,
#   3,
#   1,
#   347,
#   10,
#   18,
#   13,
#   60,
#   11,
#   13,
#   34,
#   242,
#   270,
#   139,
#   12,
#   104,
#   1670,
#   995,
#   3,
#   1,
#   367,
#   63,
#   463,
#   747,
#   440,
#   15,
#   22,
#   470,
#   59,
#   354,
#   78],
#  [1,
#   46,
#   18,
#   285,
#   473,
#   31,
#   5,
#   408,
#   218,
#   17,
#   2,
#   142,
#   15,
#   161,
#   478,
#   75,
#   5,
#   787,
#   370,
#   3,
#   2,
#   25,
#   32,
#   5,
#   748,
#   116,
#   24,
#   37,
#   26,
#   49,
#   511,
#   154,
#   88,
#   3938,
#   3,
#   24,
#   117,
#   155,
#   15,
#   73,
#   3,
#   1771,
#   36,
#   57,
#   6662,
#   1172,
#   4,
#   195,
#   7,
#   2172,
#   2,
#   83,
#   82,
#   21,
#   1,
#   1571,
#   100,
#   73,
#   2,
#   225,
#   8,
#   20,
#   2013,
#   1449,
#   3939,
#   506,
#   3,
#   1,
#   111,
#   44,
#   2,
#   83,
#   12,
#   4,
#   487,
#   36,
#   1,
#   122,
#   959,
#   1,
#   16,
#   47,
#   695,
#   804,
#   15,
#   68,
#   92,
#   84,
#   1178,
#   15,
#   2014,
#   2015,
#   20,
#   4,
#   83,
#   860,
#   13,
#   4,
#   1503,
#   508,
#   1,
#   414,
#   27,
#   26,
#   224,
#   173,
#   27,
#   1178,
#   9,
#   4,
#   213,
#   5,
#   3940,
#   55,
#   126,
#   712,
#   551,
#   1178,
#   17,
#   551,
#   6663],
#  [1,
#   14,
#   3350,
#   566,
#   5,
#   133,
#   7,
#   2942,
#   38,
#   2,
#   6664,
#   1504,
#   96,
#   316,
#   4,
#   1029,
#   3,
#   27,
#   3941,
#   15,
#   6665,
#   3942,
#   12,
#   2370,
#   1,
#   14,
#   1269,
#   335,
#   2942,
#   15,
#   3942,
#   196,
#   36,
#   82,
#   50,
#   5,
#   133,
#   7,
#   423,
#   1094,
#   98,
#   189,
#   10,
#   61,
#   7,
#   73,
#   13,
#   86,
#   3,
#   2371,
#   345,
#   1505,
#   1,
#   56,
#   128,
#   3942,
#   64,
#   42,
#   7,
#   4,
#   386,
#   3943,
#   3,
#   6,
#   1030,
#   2625,
#   1,
#   16,
#   57,
#   996,
#   2,
#   4,
#   6666,
#   17,
#   178,
#   99,
#   276,
#   16,
#   45,
#   6,
#   2943,
#   2372,
#   27,
#   110,
#   500,
#   91,
#   220,
#   13,
#   11,
#   59,
#   532,
#   2,
#   16,
#   5,
#   1030,
#   6667,
#   32,
#   18,
#   495],
#  [17,
#   23,
#   379,
#   23,
#   117,
#   1025,
#   1270,
#   11,
#   42,
#   291,
#   100,
#   222,
#   20,
#   22,
#   2944,
#   36,
#   23,
#   260,
#   2373,
#   15,
#   271,
#   886,
#   1,
#   37,
#   419,
#   105,
#   1671,
#   1506,
#   3,
#   93,
#   262,
#   71,
#   260,
#   41,
#   11,
#   723,
#   262,
#   27,
#   30,
#   90,
#   2610,
#   218,
#   17,
#   1,
#   49,
#   31,
#   1,
#   113,
#   2,
#   44,
#   11,
#   115,
#   6,
#   1030,
#   459,
#   327,
#   12,
#   421,
#   383,
#   4,
#   269,
#   13,
#   21,
#   163],
#  [27,
#   1031,
#   3,
#   16,
#   1886,
#   2945,
#   7,
#   595,
#   76,
#   20,
#   15,
#   131,
#   3944,
#   1,
#   193,
#   15,
#   264,
#   74,
#   50,
#   373,
#   20,
#   6,
#   77,
#   3,
#   156,
#   416,
#   15,
#   8,
#   12,
#   26,
#   145,
#   5,
#   131,
#   58,
#   229,
#   159,
#   2,
#   67,
#   8,
#   85,
#   340,
#   1032,
#   18,
#   200,
#   13,
#   2626,
#   3,
#   10,
#   200,
#   13,
#   2626,
#   127,
#   1,
#   16,
#   226,
#   45,
#   957,
#   116,
#   1,
#   193,
#   3,
#   158,
#   54,
#   1,
#   56,
#   44,
#   57,
#   1212,
#   215,
#   308,
#   2627,
#   63,
#   33,
#   58,
#   16,
#   5,
#   1394,
#   38,
#   10,
#   58,
#   50,
#   2626,
#   58,
#   179,
#   8,
#   383,
#   470,
#   26,
#   2626,
#   157,
#   64],
#  [43,
#   1,
#   14,
#   5,
#   645,
#   1,
#   1335,
#   5,
#   263,
#   7,
#   3945,
#   1768,
#   10,
#   562,
#   1450,
#   8,
#   761,
#   3,
#   11,
#   332,
#   31,
#   1,
#   30,
#   53,
#   26,
#   44,
#   176,
#   48,
#   11,
#   42,
#   75,
#   424,
#   1495,
#   4887,
#   2016,
#   1179,
#   10,
#   230,
#   2017,
#   11,
#   43,
#   58,
#   113,
#   1495,
#   4887,
#   2016,
#   1179,
#   3,
#   33,
#   27,
#   26,
#   761,
#   3351,
#   2,
#   120,
#   11,
#   1,
#   16,
#   5,
#   322,
#   438,
#   29,
#   30,
#   254,
#   485,
#   5,
#   343,
#   6668,
#   6669,
#   6670,
#   3352,
#   20,
#   586,
#   4888,
#   122,
#   10,
#   2,
#   8,
#   235,
#   3,
#   1,
#   347,
#   10,
#   6,
#   567,
#   13,
#   21,
#   160,
#   10,
#   1,
#   16,
#   2,
#   334,
#   6671,
#   63,
#   43,
#   27,
#   30,
#   421,
#   5,
#   1140,
#   1887,
#   28,
#   6,
#   1331,
#   3353,
#   27,
#   111,
#   239,
#   28,
#   10,
#   343,
#   3352,
#   27,
#   21,
#   392],
#  [1,
#   187,
#   46,
#   14,
#   18,
#   515,
#   143,
#   1,
#   347,
#   39,
#   29,
#   14,
#   11,
#   30,
#   108,
#   169,
#   1,
#   59,
#   187,
#   46,
#   40,
#   2,
#   107,
#   7,
#   4,
#   277],
#  [81,
#   1167,
#   12,
#   313,
#   72,
#   103,
#   278,
#   247,
#   71,
#   41,
#   79,
#   136,
#   103,
#   1138,
#   6,
#   89,
#   286,
#   71,
#   226,
#   2374,
#   35,
#   2,
#   5,
#   133,
#   7,
#   78,
#   17,
#   257,
#   45,
#   7,
#   73,
#   66,
#   2946,
#   6,
#   809,
#   2,
#   887,
#   35,
#   32,
#   68,
#   195,
#   1,
#   409,
#   262,
#   18,
#   55,
#   2,
#   37,
#   15,
#   60,
#   1,
#   51,
#   2375,
#   1494,
#   9,
#   4,
#   213,
#   17,
#   71,
#   102,
#   47,
#   114,
#   10,
#   1,
#   51,
#   159,
#   140,
#   199,
#   81,
#   1167,
#   12,
#   313,
#   72,
#   103],
#  [1,
#   312,
#   22,
#   156,
#   644,
#   3,
#   3,
#   4889,
#   28,
#   5,
#   613,
#   2947,
#   23,
#   14,
#   416,
#   32,
#   23,
#   270,
#   38,
#   15,
#   4,
#   3354,
#   299,
#   7,
#   1594,
#   5,
#   3355,
#   15,
#   5,
#   6672,
#   6673,
#   2628,
#   2,
#   11,
#   138,
#   62,
#   2018,
#   1,
#   552,
#   46,
#   23,
#   114,
#   8,
#   2,
#   643,
#   22,
#   2,
#   62,
#   206,
#   21,
#   23,
#   97,
#   37,
#   10,
#   3,
#   1,
#   126,
#   1,
#   137,
#   93,
#   11,
#   14,
#   5,
#   129,
#   299,
#   23,
#   114,
#   8,
#   33,
#   1,
#   137,
#   37,
#   11,
#   23,
#   52,
#   644,
#   643,
#   82,
#   15,
#   6,
#   172,
#   1395,
#   9,
#   4,
#   236,
#   1,
#   413,
#   524,
#   22,
#   9,
#   389,
#   3,
#   5,
#   484,
#   91],
#  [1,
#   93,
#   64,
#   23,
#   307,
#   68,
#   7,
#   2019,
#   2,
#   67,
#   283,
#   9,
#   113,
#   3,
#   23,
#   404,
#   5,
#   133,
#   7,
#   4890,
#   48,
#   161,
#   78,
#   74,
#   50,
#   79,
#   3356,
#   2,
#   22,
#   20,
#   4891,
#   43,
#   34,
#   70,
#   35,
#   34,
#   16,
#   47,
#   2607,
#   85,
#   161,
#   78,
#   3,
#   1,
#   53,
#   179,
#   58,
#   50,
#   79,
#   1070,
#   2,
#   22,
#   34,
#   109,
#   32,
#   3946,
#   148,
#   291,
#   1271,
#   3,
#   4,
#   362,
#   512,
#   23,
#   432,
#   1213,
#   2,
#   762,
#   22,
#   1507,
#   306,
#   4892,
#   22,
#   105,
#   1062,
#   13,
#   2,
#   44,
#   5,
#   206,
#   9,
#   18,
#   79,
#   3947,
#   3357,
#   15,
#   1772,
#   10,
#   965,
#   6674,
#   32,
#   4,
#   79,
#   337,
#   1180,
#   222,
#   15,
#   4,
#   160,
#   64,
#   4,
#   129,
#   92,
#   28,
#   22,
#   23,
#   13,
#   5,
#   79,
#   1133,
#   162,
#   112,
#   13,
#   3358,
#   85,
#   4,
#   445,
#   10,
#   230,
#   669,
#   22,
#   32,
#   83],
#  [1,
#   888,
#   1272,
#   12,
#   238,
#   3,
#   207,
#   47,
#   5,
#   148,
#   2,
#   49,
#   10,
#   118,
#   1,
#   205,
#   2,
#   617,
#   74,
#   1,
#   14,
#   235,
#   2,
#   4,
#   426,
#   11,
#   14,
#   4893,
#   452,
#   10,
#   427,
#   1,
#   217,
#   2,
#   25,
#   556,
#   43,
#   1,
#   471,
#   39,
#   30,
#   5,
#   237,
#   166,
#   1,
#   256,
#   157,
#   176,
#   2,
#   1255,
#   81,
#   1584,
#   2948,
#   2,
#   1773,
#   6675,
#   3,
#   541,
#   1672,
#   32,
#   4,
#   635,
#   7,
#   6,
#   83,
#   1212,
#   1,
#   14,
#   652,
#   17,
#   1,
#   46,
#   1,
#   165,
#   5,
#   1888,
#   252,
#   1214,
#   60,
#   199,
#   11,
#   13,
#   2,
#   6676,
#   556,
#   43,
#   24,
#   187,
#   375,
#   11,
#   12,
#   4,
#   241,
#   1,
#   41,
#   5,
#   1394,
#   15,
#   8,
#   3,
#   1,
#   223,
#   78,
#   2,
#   2376,
#   8,
#   5,
#   3948,
#   32,
#   184,
#   17,
#   45,
#   1,
#   100,
#   109,
#   442,
#   1033],
#  [763,
#   411,
#   18,
#   13,
#   6,
#   130,
#   269,
#   124,
#   211,
#   123,
#   1,
#   117,
#   764,
#   710,
#   20,
#   5,
#   1215,
#   174,
#   136,
#   151,
#   166,
#   1,
#   153,
#   156,
#   86,
#   32,
#   174,
#   3,
#   132,
#   2948,
#   2,
#   384,
#   17,
#   765,
#   13,
#   354,
#   492,
#   43,
#   1,
#   44,
#   20,
#   384,
#   4894,
#   115,
#   4,
#   1767,
#   6,
#   503,
#   153,
#   2,
#   2933,
#   38,
#   3,
#   1,
#   52,
#   2363,
#   5,
#   172,
#   112,
#   281,
#   8,
#   59,
#   651,
#   6,
#   345,
#   52,
#   3359,
#   739,
#   2,
#   112,
#   281,
#   8,
#   341],
#  [27,
#   385,
#   2896,
#   6,
#   817,
#   14,
#   30,
#   447,
#   3,
#   2173,
#   85,
#   5,
#   236,
#   1,
#   56,
#   93,
#   27,
#   743,
#   2,
#   4895,
#   39,
#   9,
#   4,
#   4896,
#   34,
#   491,
#   3,
#   1,
#   56,
#   46,
#   40,
#   2,
#   37,
#   71,
#   2949,
#   563,
#   3,
#   275,
#   3323,
#   7,
#   3949,
#   6677,
#   1103,
#   17,
#   58,
#   45,
#   965,
#   5,
#   4897,
#   1,
#   56,
#   16,
#   5,
#   3950,
#   2,
#   6,
#   453,
#   36,
#   27,
#   1508],
#  [81,
#   67,
#   20,
#   60,
#   2,
#   245,
#   2174,
#   1,
#   83,
#   15,
#   68,
#   258,
#   1585,
#   78,
#   3,
#   1,
#   53,
#   788,
#   43,
#   78,
#   50,
#   3360,
#   3,
#   1396,
#   1673,
#   28,
#   6,
#   191,
#   1,
#   44,
#   11,
#   68,
#   78,
#   50,
#   30,
#   59,
#   598,
#   3,
#   3360,
#   3,
#   435,
#   328,
#   60,
#   4,
#   1181,
#   1774,
#   8,
#   17,
#   1,
#   463,
#   303,
#   2174,
#   20,
#   45,
#   4,
#   92,
#   1889,
#   126,
#   92,
#   58,
#   284,
#   180,
#   219,
#   3,
#   4,
#   4898,
#   2950,
#   10,
#   6,
#   339,
#   4899,
#   87,
#   2951,
#   11,
#   60,
#   37,
#   24,
#   2175,
#   504,
#   48,
#   2174,
#   29,
#   3361,
#   15,
#   78,
#   9,
#   88,
#   290],
#  [138,
#   171,
#   1,
#   30,
#   3362,
#   3,
#   2020,
#   12,
#   11,
#   45,
#   2,
#   25,
#   90,
#   292,
#   54,
#   1,
#   6678,
#   22,
#   2,
#   245,
#   23,
#   52,
#   439,
#   79,
#   3951,
#   3342,
#   23,
#   637,
#   5,
#   133,
#   7,
#   54,
#   304,
#   28,
#   839,
#   316,
#   4,
#   186,
#   121,
#   34,
#   6679,
#   2629,
#   158,
#   96,
#   32,
#   186,
#   10,
#   9,
#   6680,
#   2377,
#   5,
#   133,
#   31,
#   150,
#   2629,
#   48,
#   22,
#   241,
#   17,
#   1,
#   6681,
#   11,
#   38,
#   2,
#   5,
#   221,
#   177,
#   150,
#   331,
#   87,
#   47,
#   9,
#   5,
#   1096,
#   141,
#   1,
#   14,
#   1216,
#   32,
#   10,
#   195,
#   3,
#   137,
#   59,
#   46,
#   40,
#   10,
#   888,
#   31,
#   459],
#  [13,
#   82,
#   459,
#   1,
#   97,
#   6682,
#   24,
#   2,
#   70,
#   5,
#   1595,
#   24,
#   150,
#   33,
#   26,
#   81,
#   200,
#   13,
#   460,
#   3,
#   709,
#   108,
#   604,
#   20,
#   5,
#   653,
#   29,
#   1509,
#   7,
#   1775,
#   1,
#   2021,
#   57,
#   798,
#   124,
#   274,
#   24,
#   45,
#   33,
#   24,
#   1171,
#   600,
#   11,
#   749,
#   4,
#   426,
#   276,
#   329,
#   269,
#   127,
#   36,
#   4,
#   533,
#   404,
#   1451,
#   1,
#   2952,
#   2,
#   750,
#   159,
#   178,
#   1,
#   53,
#   44,
#   32,
#   337,
#   818],
#  [98,
#   348,
#   12,
#   28,
#   182,
#   91,
#   1,
#   2630,
#   20,
#   6,
#   1510,
#   3,
#   289,
#   966,
#   997,
#   101,
#   35,
#   82,
#   64,
#   12,
#   4,
#   147,
#   121,
#   71,
#   2176,
#   225,
#   101,
#   9,
#   4,
#   448,
#   2177,
#   11,
#   87,
#   520,
#   4900,
#   2,
#   887,
#   154,
#   9,
#   3952,
#   29,
#   2631,
#   2,
#   1511,
#   1071,
#   142,
#   38,
#   21,
#   71,
#   681,
#   766,
#   2,
#   563,
#   448,
#   1,
#   14,
#   681,
#   258,
#   2632,
#   255,
#   3,
#   52,
#   70,
#   20,
#   82,
#   43,
#   4,
#   1273,
#   3953,
#   8,
#   29,
#   1,
#   14,
#   1332,
#   2,
#   142,
#   1,
#   471,
#   1596,
#   15,
#   90,
#   4,
#   483,
#   7,
#   4,
#   147,
#   28,
#   182,
#   280,
#   151,
#   71,
#   47,
#   20,
#   198,
#   1597],
#  [1,
#   100,
#   389,
#   4901,
#   6,
#   264,
#   150,
#   6,
#   649,
#   3,
#   9,
#   445,
#   6,
#   208,
#   3,
#   39,
#   50,
#   21,
#   410,
#   10,
#   58,
#   70,
#   20,
#   2953,
#   3,
#   70,
#   2,
#   4,
#   1512,
#   196,
#   1,
#   194,
#   651,
#   3,
#   3363,
#   85,
#   62,
#   119,
#   2,
#   25,
#   1430,
#   1,
#   14,
#   102,
#   5,
#   172,
#   1336,
#   115,
#   15,
#   73,
#   17,
#   1513,
#   42,
#   1,
#   194,
#   21,
#   3363,
#   1,
#   16,
#   225,
#   20,
#   68,
#   789,
#   112,
#   1,
#   51,
#   224,
#   62,
#   249,
#   628,
#   42,
#   19,
#   667,
#   1337,
#   2178,
#   78],
#  [71,
#   87,
#   2022,
#   2,
#   125,
#   28,
#   6,
#   86,
#   17,
#   27,
#   258,
#   224,
#   1,
#   16,
#   3364,
#   86,
#   668,
#   43,
#   1,
#   14,
#   629,
#   1,
#   217,
#   2,
#   25,
#   79,
#   4902,
#   3,
#   52,
#   128,
#   1674,
#   7,
#   2378,
#   3,
#   189,
#   4903,
#   36,
#   54,
#   164,
#   20,
#   1,
#   640,
#   6683,
#   17,
#   111,
#   1514,
#   20,
#   659,
#   7,
#   92,
#   43,
#   1,
#   164,
#   106,
#   348,
#   1,
#   1335,
#   3,
#   92,
#   87,
#   2633,
#   189,
#   63,
#   4,
#   184,
#   1452,
#   7,
#   2015,
#   29,
#   4903,
#   109,
#   30,
#   21,
#   806,
#   12,
#   8],
#  [18,
#   2379,
#   8,
#   106,
#   57,
#   2380,
#   86,
#   2179,
#   42,
#   331,
#   47,
#   452,
#   62,
#   261,
#   257,
#   158,
#   525,
#   12,
#   777,
#   1072,
#   91,
#   3,
#   23,
#   227,
#   18,
#   32,
#   4,
#   1338,
#   7,
#   5,
#   3365,
#   1,
#   328,
#   23,
#   14,
#   30,
#   159,
#   2,
#   1453,
#   22,
#   583,
#   17,
#   4,
#   935,
#   7,
#   6684,
#   14,
#   30,
#   2023,
#   1,
#   41,
#   2,
#   44,
#   104,
#   220,
#   2381,
#   701,
#   3,
#   6685,
#   956,
#   2,
#   854,
#   2,
#   22,
#   23,
#   126,
#   4,
#   261,
#   13,
#   335,
#   92,
#   861,
#   1,
#   56,
#   414,
#   11],
#  [1,
#   16,
#   696,
#   451,
#   431,
#   54,
#   257,
#   5,
#   121,
#   166,
#   144,
#   249,
#   14,
#   1274,
#   42,
#   7,
#   3924,
#   273,
#   75,
# ...
#   1376,
#   150,
#   3617,
#   1376,
#   730,
#   84,
#   154,
#   3617,
#   5505,
#   10,
#   281,
#   24,
#   49,
#   129,
#   42,
#   283,
#   352,
#   50,
#   735,
#   283,
#   352,
#   50,
#   1813,
#   24,
#   74,
#   24,
#   50,
#   24,
#   50,
#   619,
#   24,
#   50,
#   1237,
#   24,
#   50,
#   3,
#   4026,
#   162,
#   2,
#   25,
#   154,
#   15,
#   9,
#   6,
#   475,
#   1,
#   49,
#   9,
#   4505,
#   43,
#   142,
#   379,
#   2,
#   8,
#   3749,
#   107,
#   8,
#   49,
#   8499,
#   8500,
#   4,
#   209,
#   481,
#   15,
#   88,
#   20,
#   352,
#   3,
#   4506,
#   866,
#   40,
#   24,
#   5769,
#   158,
#   54,
#   2063,
#   43,
#   24,
#   5770,
#   504,
#   93,
#   7,
#   504,
#   9,
#   5,
#   118,
#   10,
#   281,
#   24,
#   49,
#   129,
#   31,
#   1376,
#   49,
#   8501,
#   1376,
#   150,
#   8502,
#   1376,
#   150,
#   84,
#   3750,
#   1376,
#   708,
#   31,
#   6,
#   169,
#   8503,
#   2493,
#   145,
#   21,
#   94,
#   8504,
#   2493,
#   32,
#   1537,
#   3,
#   8505,
#   24,
#   50,
#   76,
#   9,
#   4,
#   157,
#   118,
#   4,
#   157,
#   2402,
#   516,
#   3,
#   4507,
#   15,
#   88,
#   1186,
#   3,
#   8506,
#   48,
#   80,
#   460,
#   2,
#   80,
#   8507,
#   3,
#   4500,
#   150,
#   11,
#   13,
#   735,
#   12,
#   24,
#   283,
#   352,
#   3,
#   4506,
#   50,
#   4,
#   907,
#   10,
#   66,
#   2963,
#   24,
#   9,
#   514,
#   572,
#   3,
#   10,
#   66,
#   612,
#   24,
#   4,
#   8508,
#   1369,
#   12,
#   24,
#   3,
#   12,
#   88,
#   89,
#   229,
#   3197,
#   73,
#   414,
#   9,
#   73,
#   8509,
#   504,
#   9,
#   73],
#  [34,
#   109,
#   1659,
#   9,
#   4,
#   4508,
#   2845,
#   3,
#   23,
#   1934,
#   158,
#   621,
#   58,
#   114,
#   22,
#   28,
#   11,
#   84,
#   381,
#   1,
#   226,
#   21,
#   199,
#   2,
#   816,
#   11,
#   2,
#   22,
#   90,
#   4,
#   91,
#   23,
#   87,
#   2431,
#   63,
#   64,
#   23,
#   859,
#   2116,
#   2,
#   8,
#   42,
#   27,
#   4,
#   8510,
#   12,
#   1398,
#   589,
#   40,
#   6,
#   119,
#   55,
#   231,
#   34,
#   109,
#   21,
#   410,
#   43,
#   109,
#   924,
#   42,
#   75,
#   45,
#   34,
#   41],
#  [1,
#   14,
#   286,
#   498,
#   15,
#   191,
#   8511,
#   2281,
#   17,
#   309,
#   26,
#   57,
#   3384,
#   1268,
#   21,
#   513,
#   75,
#   47,
#   198,
#   91,
#   123,
#   1,
#   8512,
#   6,
#   908,
#   74,
#   545,
#   8,
#   12,
#   198,
#   91,
#   36,
#   146,
#   356,
#   42,
#   1,
#   14,
#   21,
#   629,
#   386,
#   186,
#   348,
#   78,
#   16,
#   8513,
#   4,
#   5771,
#   7,
#   6,
#   273,
#   112,
#   2136,
#   9,
#   8,
#   1467,
#   11,
#   48,
#   4,
#   426,
#   10,
#   1176,
#   17,
#   75,
#   26,
#   36,
#   160,
#   36,
#   40,
#   11,
#   227,
#   2,
#   8,
#   20,
#   659,
#   7,
#   2122,
#   86,
#   28,
#   765,
#   89,
#   1,
#   16,
#   5,
#   869,
#   363,
#   7,
#   2724,
#   10,
#   1,
#   137,
#   672,
#   1,
#   41,
#   178,
#   1,
#   359,
#   9,
#   15,
#   6,
#   587,
#   251],
#  [17,
#   813,
#   230,
#   1841,
#   2,
#   37,
#   21,
#   64,
#   1,
#   409,
#   6,
#   620,
#   13,
#   60,
#   37,
#   1,
#   326,
#   5772,
#   101,
#   955,
#   48,
#   39,
#   182,
#   25,
#   72,
#   5773,
#   43,
#   702,
#   15,
#   39,
#   198,
#   1693,
#   101,
#   38,
#   2,
#   25,
#   5,
#   1599,
#   3,
#   342,
#   8514,
#   162,
#   10,
#   203,
#   447,
#   2137,
#   1581,
#   158,
#   54,
#   1,
#   370,
#   15,
#   39],
#  [19,
#   394,
#   28,
#   18,
#   19,
#   1468,
#   8,
#   33,
#   1,
#   65,
#   2,
#   245,
#   27,
#   4509,
#   1563,
#   21,
#   712,
#   7,
#   483,
#   1,
#   65,
#   2,
#   245,
#   19,
#   2604,
#   8,
#   12,
#   5,
#   301,
#   7,
#   440,
#   3,
#   99,
#   19,
#   1147,
#   304,
#   28,
#   2661,
#   127,
#   63,
#   197,
#   1516,
#   729,
#   38,
#   4,
#   547,
#   3234,
#   151,
#   166],
#  [418,
#   2,
#   81,
#   579,
#   7,
#   67,
#   25,
#   11,
#   906,
#   155,
#   9,
#   4,
#   1545,
#   155,
#   9,
#   8515,
#   57,
#   809,
#   7,
#   5104,
#   3,
#   29,
#   759,
#   3751,
#   2,
#   81,
#   105,
#   957,
#   2,
#   234,
#   12,
#   67,
#   52,
#   25,
#   464,
#   240,
#   2,
#   155,
#   15,
#   228,
#   350,
#   1097,
#   29,
#   2282,
#   424,
#   36,
#   2852,
#   1965,
#   29,
#   2578,
#   1,
#   16,
#   888,
#   9,
#   4,
#   423,
#   625,
#   17,
#   1247,
#   7,
#   4,
#   105,
#   3235,
#   3713,
#   375,
#   31,
#   4510,
#   957,
#   2,
#   234,
#   12,
#   18,
#   579,
#   7,
#   67,
#   1,
#   16,
#   888,
#   32,
#   586,
#   5774,
#   17,
#   4,
#   338,
#   7,
#   1050,
#   8516],
#  [1,
#   229,
#   156,
#   1399,
#   79,
#   388,
#   322,
#   467,
#   29,
#   86,
#   467,
#   27,
#   26,
#   224,
#   33,
#   1,
#   49,
#   363,
#   1,
#   56,
#   63,
#   46,
#   40,
#   4,
#   80,
#   13,
#   42,
#   1,
#   1160,
#   171,
#   388,
#   911,
#   1556,
#   58,
#   147,
#   5,
#   8517,
#   388,
#   719,
#   54,
#   3,
#   13,
#   4,
#   425,
#   80,
#   5775,
#   2,
#   8,
#   68,
#   1215,
#   168,
#   1,
#   53,
#   87,
#   312,
#   1166,
#   11,
#   75,
#   799,
#   108,
#   10,
#   8518,
#   197,
#   75,
#   5,
#   2536,
#   80,
#   1556],
#  [64,
#   148,
#   712,
#   11,
#   97,
#   16,
#   676,
#   8,
#   592,
#   440,
#   2,
#   656,
#   35,
#   4,
#   4186,
#   8519,
#   11,
#   14,
#   442,
#   42,
#   238,
#   11,
#   14,
#   182,
#   592,
#   1,
#   848,
#   11,
#   14,
#   54,
#   2,
#   107,
#   4,
#   451,
#   3752,
#   3,
#   1,
#   164,
#   2,
#   375,
#   12,
#   4,
#   172,
#   8520,
#   34,
#   225,
#   4,
#   319,
#   9,
#   3,
#   58,
#   109,
#   468,
#   1,
#   14,
#   4511,
#   255,
#   12,
#   73,
#   3,
#   1,
#   223,
#   6,
#   2525,
#   33,
#   23,
#   471,
#   73,
#   23,
#   1528,
#   9,
#   5,
#   3183,
#   2706,
#   10,
#   23,
#   317,
#   165,
#   3752,
#   3,
#   33,
#   23,
#   165,
#   3752,
#   23,
#   52,
#   16,
#   47,
#   157,
#   9,
#   618,
#   7,
#   8,
#   42,
#   34,
#   109,
#   9,
#   5,
#   79,
#   408,
#   1480,
#   3,
#   33,
#   1,
#   109,
#   82,
#   1,
#   8521,
#   52,
#   16,
#   733,
#   3,
#   43,
#   1,
#   270,
#   35,
#   7,
#   18,
#   4114,
#   1,
#   14,
#   59,
#   8522,
#   3,
#   341],
#  [11,
#   45,
#   13,
#   30,
#   21,
#   8523,
#   24,
#   46,
#   1,
#   51,
#   5388,
#   15,
#   3236,
#   1149,
#   191,
#   258,
#   554,
#   937,
#   3237,
#   8524,
#   3,
#   271,
#   1,
#   16,
#   5,
#   1554,
#   121,
#   220,
#   399,
#   15,
#   431,
#   2355,
#   26,
#   32,
#   45,
#   937,
#   2555,
#   74,
#   270,
#   90,
#   147,
#   1766,
#   3,
#   637,
#   528,
#   293,
#   159,
#   2,
#   155,
#   1649,
#   8,
#   106,
#   76,
#   2,
#   57,
#   5529,
#   206,
#   2,
#   204,
#   22,
#   4046,
#   1,
#   752,
#   214,
#   303,
#   166,
#   3,
#   122,
#   26,
#   65,
#   2,
#   17,
#   333,
#   972,
#   2,
#   70,
#   90,
#   15,
#   22,
#   4,
#   1292,
#   55,
#   3158,
#   3,
#   5,
#   258,
#   160,
#   4943,
#   1407],
#  [227,
#   125,
#   16,
#   81,
#   361,
#   156,
#   5,
#   311,
#   2444,
#   211,
#   123,
#   6,
#   5776,
#   817,
#   8525,
#   20,
#   8,
#   43,
#   1,
#   14,
#   145,
#   5,
#   322,
#   438,
#   71,
#   47,
#   239,
#   5,
#   817,
#   97,
#   25,
#   129,
#   12,
#   8,
#   17,
#   60,
#   37,
#   1,
#   204,
#   5,
#   817,
#   10,
#   317,
#   13,
#   29,
#   53,
#   25,
#   2195,
#   2,
#   8526,
#   43,
#   27,
#   341,
#   29,
#   549,
#   29,
#   145,
#   191,
#   830,
#   3,
#   181,
#   8527,
#   15,
#   8,
#   3,
#   8528,
#   3,
#   107,
#   8,
#   49,
#   344,
#   53,
#   1,
#   44,
#   61,
#   309,
#   317,
#   2195,
#   29,
#   60,
#   52,
#   34,
#   1584,
#   61,
#   34,
#   3475,
#   2,
#   2321,
#   1465,
#   542,
#   7,
#   1644,
#   48,
#   8529,
#   17,
#   60,
#   37,
#   34,
#   1584],
#  [763,
#   1187,
#   426,
#   7,
#   557,
#   6,
#   251,
#   3,
#   1,
#   2321,
#   1465,
#   9,
#   113,
#   1708,
#   2003,
#   73,
#   12,
#   356,
#   163,
#   11,
#   1115,
#   2,
#   204,
#   73,
#   5,
#   139,
#   17,
#   18,
#   272,
#   13,
#   108,
#   2305,
#   3,
#   1,
#   93,
#   268,
#   962,
#   15,
#   167,
#   12,
#   129,
#   62,
#   453,
#   13,
#   679,
#   3,
#   19,
#   14,
#   4356,
#   85,
#   57,
#   4072,
#   48,
#   68,
#   78,
#   74,
#   1782,
#   1648,
#   12,
#   39,
#   3189,
#   3,
#   470,
#   76,
#   2,
#   5777,
#   39,
#   885,
#   99,
#   18,
#   8530,
#   8531,
#   782,
#   114,
#   39,
#   11,
#   14,
#   39,
#   29,
#   4,
#   502,
#   3,
#   21,
#   19,
#   14,
#   2948,
#   5,
#   759,
#   43,
#   1,
#   1095,
#   38,
#   3,
#   336,
#   39,
#   9],
#  [95,
#   695,
#   2,
#   656,
#   35,
#   1769,
#   321,
#   15,
#   8,
#   32,
#   4,
#   382,
#   95,
#   682,
#   40,
#   841,
#   24,
#   45,
#   2,
#   204,
#   35,
#   10,
#   24,
#   285,
#   16,
#   191,
#   14,
#   11,
#   108,
#   24,
#   628,
#   504,
#   122,
#   119,
#   1248,
#   195,
#   11,
#   35,
#   306],
#  [232,
#   37,
#   26,
#   347,
#   39,
#   712,
#   19,
#   336,
#   22,
#   423,
#   21,
#   233,
#   188,
#   24,
#   53,
#   180,
#   10,
#   19,
#   143,
#   16,
#   524,
#   4,
#   1974,
#   29,
#   513,
#   17,
#   538,
#   69,
#   19,
#   2085,
#   16,
#   19,
#   570,
#   1246,
#   881,
#   293,
#   5,
#   96,
#   9,
#   2899,
#   3659,
#   2933,
#   10,
#   13,
#   69,
#   343,
#   2059,
#   7,
#   5,
#   96,
#   2,
#   311,
#   62,
#   1739,
#   23,
#   52,
#   107,
#   224,
#   1,
#   14,
#   8532,
#   9,
#   384,
#   85,
#   4,
#   54,
#   19,
#   100,
#   139,
#   3,
#   40,
#   172,
#   2261,
#   1,
#   100,
#   2,
#   120,
#   39,
#   19,
#   52,
#   16,
#   317,
#   609,
#   48,
#   22,
#   1,
#   14,
#   646,
#   68,
#   118,
#   29,
#   228,
#   3,
#   16,
#   4,
#   3753,
#   1,
#   14,
#   159,
#   2,
#   951],
#  [756,
#   2182,
#   1158,
#   176,
#   12,
#   1790,
#   945,
#   1,
#   51,
#   21,
#   1003,
#   3,
#   1,
#   56,
#   46,
#   40,
#   2,
#   37,
#   29,
#   74,
#   2,
#   1047,
#   35,
#   2,
#   1,
#   153,
#   448,
#   6,
#   251,
#   214,
#   91,
#   166,
#   43,
#   1,
#   359,
#   176,
#   48,
#   6,
#   139,
#   2,
#   5,
#   169,
#   622,
#   12,
#   5,
#   131,
#   19,
#   14,
#   1140,
#   2732,
#   3,
#   79,
#   3221],
#  [1803,
#   1,
#   52,
#   2977,
#   290,
#   851,
#   4,
#   130,
#   428,
#   1157,
#   15,
#   11,
#   50,
#   443,
#   3,
#   24,
#   53,
#   1486,
#   33,
#   24,
#   65,
#   2,
#   750,
#   29,
#   26,
#   12,
#   5,
#   2595,
#   17,
#   11,
#   13,
#   5,
#   129,
#   527,
#   200,
#   12,
#   5778,
#   8533,
#   1,
#   153,
#   15,
#   290,
#   851,
#   17,
#   64,
#   37,
#   5779,
#   1803,
#   132,
#   3,
#   98,
#   1,
#   246,
#   1,
#   845,
#   2,
#   18,
#   244,
#   1,
#   31,
#   4,
#   5658,
#   21,
#   309,
#   173,
#   1,
#   2049,
#   11,
#   33,
#   24,
#   56,
#   31,
#   18,
#   61,
#   24,
#   53,
#   30,
#   3039,
#   38,
#   5779,
#   1803,
#   505,
#   20,
#   1895,
#   29,
#   16,
#   69,
#   505,
#   38,
#   2,
#   24,
#   17,
#   1,
#   52,
#   297,
#   290,
#   851,
#   33,
#   24,
#   50,
#   5,
#   5778,
#   32,
#   337,
#   12,
#   4,
#   130,
#   428,
#   1157],
#  [45,
#   10,
#   43,
#   470,
#   26,
#   196,
#   9,
#   4,
#   3397,
#   34,
#   155,
#   138,
#   1177,
#   4,
#   1182,
#   914,
#   8534,
#   3,
#   82,
#   397,
#   61,
#   8535,
#   17,
#   75,
#   30,
#   10,
#   434,
#   5,
#   133,
#   7,
#   11,
#   157,
#   64,
#   27,
#   1792,
#   22,
#   12,
#   2326,
#   7,
#   683,
#   440,
#   29,
#   21,
#   17,
#   1,
#   49,
#   160,
#   23,
#   13,
#   10,
#   8536,
#   10,
#   11,
#   281,
#   8,
#   392,
#   1,
#   16,
#   2,
#   709,
#   171,
#   9,
#   5,
#   163,
#   728,
#   769,
#   15,
#   1323,
#   2292,
#   1437,
#   36,
#   489,
#   36,
#   1,
#   254,
#   2516,
#   23,
#   1147,
#   3754],
#  [19,
#   41,
#   266,
#   7,
#   62,
#   192,
#   84,
#   57,
#   1575,
#   12,
#   61,
#   161,
#   266,
#   1457,
#   2,
#   6,
#   86,
#   39,
#   373,
#   32,
#   4,
#   1317,
#   674,
#   6,
#   4285,
#   20,
#   5780,
#   1,
#   111,
#   619,
#   39,
#   197,
#   21,
#   1,
#   521,
#   984,
#   11,
#   289,
#   222,
#   197],
#  [12,
#   45,
#   4,
#   160,
#   10,
#   857,
#   20,
#   4,
#   811,
#   82,
#   13,
#   111,
#   2078,
#   7,
#   129,
#   2,
#   25,
#   41,
#   238,
#   127,
#   274,
#   24,
#   79,
#   94,
#   2,
#   230,
#   74,
#   432,
#   165,
#   6,
#   89,
#   1218,
#   1,
#   59,
#   776,
#   11,
#   3238,
#   276,
#   63,
#   248,
#   557,
#   5,
#   4178,
#   35,
#   9,
#   6,
#   1691,
#   121,
#   1262,
#   274,
#   24,
#   127,
#   230,
#   334,
#   1479],
#  [1,
#   205,
#   2,
#   4410,
#   5,
#   169,
#   4484,
#   9,
#   6,
#   169,
#   537,
#   17,
#   413,
#   41,
#   54,
#   2,
#   5781,
#   2,
#   313,
#   11,
#   446,
#   462,
#   1,
#   49,
#   31,
#   1,
#   14,
#   4,
#   110,
#   61,
#   335,
#   11,
#   861,
#   3,
#   75,
#   1303,
#   5,
#   1178,
#   939,
#   6,
#   338,
#   13,
#   10,
#   61,
#   7,
#   4,
#   3575,
#   13,
#   724,
#   8,
#   5,
#   133,
#   7,
#   1525,
#   519,
#   615,
#   478,
#   12,
#   798,
#   276,
#   1716,
#   696,
#   188,
#   9,
#   444,
#   354,
#   8537,
#   34,
#   297,
#   2,
#   831,
#   5586,
#   2,
#   57,
#   253,
#   7,
#   121,
#   8538,
#   860,
#   3,
#   627,
#   134,
#   37,
#   10,
#   23,
#   225,
#   2311,
#   20,
#   5,
#   380,
#   643,
#   3,
#   114,
#   365,
#   2,
#   37,
#   4,
#   209,
#   9,
#   3965,
#   7,
#   6,
#   717,
#   3634,
#   2,
#   831,
#   8,
#   542,
#   12,
#   344,
#   2369,
#   7,
#   1250,
#   2572,
#   50,
#   325,
#   15,
#   8539,
#   1049,
#   29,
#   484,
#   5782,
#   112,
#   479,
#   1,
#   111,
#   16,
#   2,
#   4512,
#   152],
#  [235,
#   1,
#   102,
#   41,
#   2,
#   709,
#   152,
#   45,
#   4,
#   874,
#   1,
#   97,
#   93,
#   7,
#   99,
#   225,
#   5,
#   2565,
#   219,
#   2,
#   292,
#   621,
#   10,
#   1,
#   194,
#   8540,
#   4,
#   1052,
#   15,
#   8541,
#   3,
#   4,
#   219,
#   1203,
#   1168,
#   57,
#   8542,
#   7,
#   5,
#   1146,
#   503,
#   1,
#   41,
#   2,
#   225,
#   292,
#   2565,
#   1052,
#   116,
#   1,
#   49,
#   11,
#   20,
#   6,
#   503,
#   95,
#   1819,
#   1926,
#   42,
#   132,
#   45,
#   7,
#   18,
#   889,
#   47,
#   335,
#   8,
#   79,
#   861,
#   3,
#   600,
#   15,
#   21,
#   94,
#   3,
#   64,
#   1,
#   49,
#   31,
#   889,
#   84,
#   8543,
#   143,
#   1,
#   30,
#   120,
#   116,
#   18,
#   1115,
#   8,
#   29,
#   215,
#   22,
#   46,
#   10,
#   18,
#   307,
#   1178,
#   3,
#   4513,
#   32,
#   6,
#   996,
#   219,
#   183],
#  [1,
#   49,
#   31,
#   1,
#   53,
#   25,
#   10,
#   162,
#   12,
#   6,
#   456,
#   123,
#   1,
#   150,
#   22,
#   17,
#   1,
#   56,
#   93,
#   1,
#   65,
#   2,
#   4514,
#   6,
#   1788,
#   12,
#   10,
#   1,
#   30,
#   65,
#   2,
#   16,
#   5,
#   1452,
#   89,
#   3,
#   204,
#   142,
#   74,
#   66,
#   16,
#   54,
#   12,
#   8,
#   1,
#   137,
#   1771,
#   38,
#   9,
#   5,
#   1133,
#   119,
#   31,
#   22,
#   75,
#   26,
#   149,
#   28,
#   175,
#   1,
#   1222,
#   38,
#   3755,
#   17,
#   82,
#   13,
#   26,
#   94,
#   150,
#   9,
#   4,
#   119,
#   1,
#   1222,
#   38,
#   9,
#   21,
#   175,
#   397,
#   631,
#   2,
#   8],
#  [756,
#   230,
#   27,
#   189,
#   57,
#   1589,
#   12,
#   5,
#   296,
#   287,
#   2061,
#   3,
#   1,
#   59,
#   65,
#   2,
#   709,
#   28,
#   1671,
#   1102,
#   20,
#   4,
#   5783,
#   20,
#   1842,
#   38,
#   76,
#   2,
#   1192,
#   67,
#   48,
#   5,
#   1521,
#   1,
#   52,
#   150,
#   2,
#   550,
#   88,
#   596,
#   173,
#   24,
#   164,
#   153,
#   1842,
#   38,
#   40,
#   24,
#   16,
#   1134,
#   3,
#   60,
#   11,
#   55,
#   3239,
#   88,
#   89,
#   7,
#   483,
#   171,
#   24,
#   709,
#   66,
#   25,
#   1666,
#   20,
#   6,
#   269,
#   1,
#   53,
#   63,
#   248,
#   24,
#   5,
#   5784,
#   453,
#   33,
#   24,
#   52,
#   31,
#   30,
#   215,
#   8,
#   46,
#   49,
#   443,
#   2,
#   1371,
#   152,
#   1113,
#   29,
#   769,
#   8,
#   33,
#   24,
#   65,
#   2,
#   25,
#   72,
#   1041,
#   327],
#  [17,
#   1,
#   16,
#   108,
#   1,
#   93,
#   13,
#   631,
#   222,
#   2,
#   32,
#   337,
#   25,
#   580,
#   88,
#   54,
#   95,
#   156,
#   4,
#   621,
#   35,
#   28,
#   6,
#   5785,
#   855,
#   1945,
#   23,
#   30,
#   100,
#   4,
#   769,
#   77,
#   235,
#   48,
#   22,
#   2329,
#   2663,
#   22,
#   1132,
#   12,
#   22,
#   855,
#   8544,
#   163,
#   391,
#   388,
#   18,
#   14,
#   4515,
#   12,
#   167,
#   34,
#   50,
#   242,
#   258,
#   8545,
#   78,
#   10,
#   210,
#   2,
#   826,
#   104,
#   175,
#   17,
#   2989,
#   32,
#   747,
#   3,
#   1219,
#   34,
#   1013,
#   41,
#   94,
#   54,
#   636,
#   7,
#   139,
#   2,
#   8546,
#   222,
#   1559,
#   18,
#   855,
#   13,
#   5,
#   1255,
#   1377,
#   356,
#   36,
#   33,
#   23,
#   687,
#   44,
#   11,
#   23,
#   66,
#   16,
#   5,
#   3756,
#   2853,
#   679,
#   7,
#   949,
#   422,
#   3757,
#   2725,
#   29,
#   33,
#   889,
#   1426,
#   30,
#   737,
#   2,
#   211,
#   585,
#   38,
#   29,
#   152,
#   2332],
#  [11,
#   281,
#   677,
#   2,
#   120,
#   1036,
#   154,
#   158,
#   2824,
#   17,
#   1,
#   499,
#   1,
#   97,
#   204,
#   5,
#   200,
#   116,
#   11,
#   397,
#   21,
#   1341,
#   1,
#   419,
#   5,
#   391,
#   4,
#   105,
#   96,
#   28,
#   142,
#   74,
#   367,
#   83,
#   282,
#   3,
#   30,
#   360,
#   2,
#   25,
#   32,
#   139],
#  [1,
#   49,
#   31,
#   32,
#   18,
#   195,
#   27,
#   4,
#   110,
#   61,
#   997,
#   1092,
#   106,
#   104,
#   141,
#   71,
#   1473,
#   335,
#   54,
#   2,
#   2359,
#   21,
#   10,
#   19,
#   97,
#   93,
#   92,
#   138,
#   335,
#   5,
#   374,
#   304,
#   28,
#   11,
#   917,
#   38,
#   34,
#   59,
#   110,
#   53,
#   120,
#   292,
#   105,
#   20,
#   4,
#   2041,
#   330,
#   2,
#   1078,
#   306,
#   111,
#   4,
#   388,
#   1049,
#   268,
#   153,
#   2,
#   26,
#   1372,
#   2,
#   8,
#   34,
#   155,
#   138,
#   57,
#   974,
#   10,
#   1952,
#   43,
#   4,
#   105,
#   55,
#   419,
#   4,
#   769,
#   1,
#   46,
#   62,
#   746,
#   1832,
#   21,
#   1,
#   46,
#   43,
#   34,
#   53,
#   753,
#   77,
#   19,
#   2637,
#   62,
#   259,
#   396],
#  [492,
#   98,
#   292,
#   1291,
#   1,
#   44,
#   5,
#   2854,
#   102,
#   1,
#   117,
#   179,
#   33,
#   27,
#   949,
#   324,
#   42,
#   1,
#   122,
#   1715,
#   20,
#   6,
#   160,
#   932,
#   596,
#   3,
#   49,
#   318,
#   64,
#   4,
#   706,
#   7,
#   40,
#   27,
#   702,
#   15,
#   13,
#   652,
#   1014,
#   567,
#   112,
#   14,
#   4516,
#   21,
#   27,
#   239,
#   1715,
#   13,
#   30,
#   2171,
#   35,
#   161,
#   403,
#   3,
#   313,
#   6,
#   503,
#   439,
#   79,
#   1573,
#   123,
#   377,
#   8547,
#   11,
#   2,
#   26,
#   373,
#   25,
#   4254,
#   1362,
#   3,
#   341,
#   899,
#   41,
#   5,
#   136,
#   496,
#   2789,
#   42,
#   98,
#   68,
#   1157,
#   1,
#   647,
#   106,
#   5,
#   5786,
#   42,
#   4,
#   474,
#   1049,
#   50,
#   21,
#   1910,
#   61,
#   1291,
#   165,
#   4,
#   256,
#   423,
#   7,
#   6,
#   427,
#   1846],
#  [17,
#   11,
#   53,
#   25,
#   231,
#   15,
#   81,
#   1966,
#   2295,
#   102,
#   212,
#   524,
#   8548,
#   8549,
#   20,
#   2821,
#   8550,
#   83,
#   30,
#   16,
#   2,
#   25,
#   2770,
#   3,
#   1402,
#   3,
#   93,
#   28,
#   40,
#   3758,
#   254,
#   652,
#   29,
#   83,
#   45,
#   174,
#   1,
#   120,
#   1506,
#   28,
#   1983,
#   1347,
#   38,
#   3,
#   11,
#   949,
#   199,
#   9,
#   5,
#   408,
#   1695,
#   1,
#   1280,
#   15,
#   6,
#   456,
#   9,
#   5,
#   8551,
#   8552,
#   12,
#   825,
#   151],
#  [4247,
#   221,
#   54,
#   2,
#   4410,
#   5,
#   3122,
#   14,
#   747,
#   91,
#   166,
#   4,
#   497,
#   221,
#   54,
#   13,
#   235,
#   510,
#   6,
#   169,
#   1331,
#   3712,
#   1,
#   46,
#   86,
#   8553,
#   45,
#   7,
#   167,
#   17,
#   33,
#   34,
#   53,
#   3467,
#   61,
#   1452,
#   3328,
#   10,
#   2168,
#   47,
#   997,
#   115,
#   207,
#   61,
#   245,
#   1451,
#   2,
#   1302,
#   235,
#   1,
#   100,
#   5,
#   5787,
#   1,
#   165,
#   2802,
#   12,
#   151,
#   3,
#   521,
#   8554,
#   6,
#   1982],
#  [1889,
#   231,
#   5,
#   133,
#   309,
#   673,
#   152,
#   6,
#   342,
#   1677,
#   3,
#   424,
#   17,
#   1889,
#   102,
#   231,
#   5,
#   133,
#   12,
#   8,
#   140,
#   1,
#   16,
#   5,
#   139,
#   27,
#   146,
#   2557,
#   1,
#   16,
#   6,
#   192,
#   2855,
#   1,
#   16,
#   5,
#   236,
#   3,
#   1,
#   16,
#   68,
#   1187,
#   569,
#   15,
#   73,
#   43,
#   1,
#   14,
#   1917,
#   58,
#   270,
#   2,
#   6,
#   2321,
#   3,
#   373,
#   1356,
#   38,
#   12,
#   8,
#   43,
#   978,
#   170,
#   1934,
#   8,
#   294,
#   725,
#   4,
#   184,
#   514,
#   264,
#   1,
#   53,
#   234,
#   12,
#   3,
#   105,
#   188,
#   27,
#   315,
#   7,
#   73,
#   6,
#   261,
#   397,
#   10,
#   160,
#   17,
#   6,
#   349,
#   13,
#   4,
#   425],
#  ...]
